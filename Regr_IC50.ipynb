# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor, ExtraTreesRegressor
from catboost import CatBoostRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import optuna

# %%
# Устанавливаем глобальное начальное состояние генератора случайных чисел
np.random.seed(42)

# %%
df = pd.read_csv('data/df_ic50_iqr.csv')

# %%
# Разделяем данные
X = df.drop(columns=['IC50'])
y = df['IC50']

# %%
# Делим исходные данные на тренировочную и тестовую выборки
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Теперь необходимо выбрать оптимальную модель.
#
# Для построения предсказательной модели были рассмотрены следующие алгоритмы:
#
# * XGBRegressor;
#
# * XGBRegressor с функцией потерь Tweedie;
#
# * RandomForestRegressor;
#
# * GradientBoostingRegressor;
#
# * CatBoostRegressor;
#
# * CatBoostRegressor с функцией потерь Tweedie ;
#
# * HistGradientBoostingRegressor;
#
# * ExtraTreesRegressor.
#
# Так как все перечисленные алгоритмы основаны на деревьях решений, они не чувствительны к масштабу признаков и не требуют стандартизации или нормализации входных данных. Кроме того, методы снижения размерности, такие как PCA, также не обязательны, поскольку деревья эффективно справляются с избыточностью и коррелированными признаками.
#
# Таким образом, подготовленные данные были напрямую переданы в модели без предварительной стандартизации или понижения размерности.

# %%
models = {
    'XGB': XGBRegressor(),
    'XGB_Tweedie': XGBRegressor(objective='reg:tweedie'),
    'RandomForest': RandomForestRegressor(),
    'GradientBoosting': GradientBoostingRegressor(),
    'CatBoost': CatBoostRegressor(verbose=0),
    'CatBoost_Tweedie': CatBoostRegressor(verbose=0, loss_function='Tweedie:variance_power=1.4'),
    'HistGradientBoostingRegressor': HistGradientBoostingRegressor(),
    'ExtraTreesRegressor': ExtraTreesRegressor()
}

# %%
def evaluate_models(models, X_train_full, y_train_full, X_test, y_test):
    results = []

    for name, model in models.items():
        pipeline = Pipeline([
            ('regressor', model)
        ])

        pipeline.fit(X_train_full, y_train_full)
        y_pred = pipeline.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)

        results.append({
            'Model': name,
            'R2': round(r2, 4),
            'RMSE': round(rmse, 4),
            'MAE': round(mae, 4),
            'Tuned': False
        })

    return pd.DataFrame(results)
results_untuned = evaluate_models(models, X_train_full, y_train_full, X_test, y_test)
display(results_untuned)
# Out:
#                            Model      R2      RMSE      MAE  Tuned
# 0                            XGB  0.1210   97.1841  58.8789  False
# 1                    XGB_Tweedie  0.3023   86.5880  48.1642  False
# 2                   RandomForest  0.1687   94.5122  58.7291  False
# 3               GradientBoosting  0.1889   93.3546  61.9057  False
# 4                       CatBoost  0.2102   92.1207  57.8841  False
# 5               CatBoost_Tweedie  0.3215   85.3831  48.0945  False
# 6  HistGradientBoostingRegressor  0.0070  103.2943  64.3260  False
# 7            ExtraTreesRegressor  0.2115   92.0490  58.9141  False

# %%
def plot_metrics_comparison(results_df):
    metrics = ['R2', 'RMSE', 'MAE']
    fig, axs = plt.subplots(1, 3, figsize=(18, 5))

    for i, metric in enumerate(metrics):
        sns.barplot(data=results_df, x='Model', y=metric, ax=axs[i])
        axs[i].set_title(f'Сравнение моделей по {metric}')
        axs[i].set_xticks(range(len(results_df['Model'])))
        axs[i].set_xticklabels(results_df['Model'], rotation=45, ha='right')

    plt.tight_layout()
    plt.show()

plot_metrics_comparison(results_untuned)

# %%
def optuna_tuning(models, n_trials=50):
    results = []
    trained_models = {}

    # Проходим по всем моделям из переданного словаря
    for model_key, model in models.items():
        # Разбиваем данные на train/validation
        X_train, X_valid, y_train, y_valid = train_test_split(
            X_train_full, y_train_full, test_size=0.2, random_state=42
        )

        # Определяем функцию-цель для Optuna
        def objective(trial):
            # Для каждой модели формируем свой словарь параметров
            if model_key == 'XGB':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 500),
                    'max_depth': trial.suggest_int('max_depth', 3, 10),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'subsample': trial.suggest_float('subsample', 0.5, 1.0),
                    'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
                    'gamma': trial.suggest_float('gamma', 0, 5),
                    'min_child_weight': trial.suggest_int('min_child_weight', 1, 10)
                }
                reg = XGBRegressor(**params)

            elif model_key == 'XGB_Tweedie':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 500),
                    'max_depth': trial.suggest_int('max_depth', 3, 10),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'subsample': trial.suggest_float('subsample', 0.5, 1.0),
                    'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
                    'gamma': trial.suggest_float('gamma', 0, 5),
                    'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
                    'tweedie_variance_power': trial.suggest_float('tweedie_variance_power', 1.1, 1.9)
                }
                reg = XGBRegressor(**params, objective='reg:tweedie')

            elif model_key == 'RandomForest':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 300),
                    'max_depth': trial.suggest_int('max_depth', 3, 20),
                    'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
                    'max_features': trial.suggest_categorical('max_features', ['log2', 'sqrt', None])
                }
                reg = RandomForestRegressor(**params)

            elif model_key == 'GradientBoosting':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 300),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'max_depth': trial.suggest_int('max_depth', 3, 10),
                    'subsample': trial.suggest_float('subsample', 0.5, 1.0),
                    'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
                    'max_features': trial.suggest_categorical('max_features', [None, 'sqrt', 'log2'])
                }
                reg = GradientBoostingRegressor(**params, random_state=42)

            elif model_key == 'CatBoost':
                params = {
                    'iterations': trial.suggest_int('iterations', 100, 1000),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'depth': trial.suggest_int('depth', 4, 10),
                    'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 10),
                    'bagging_temperature': trial.suggest_float('bagging_temperature', 0, 1)
                }
                reg = CatBoostRegressor(**params, verbose=False)

            elif model_key == 'CatBoost_Tweedie':
                # Задаем Tweedie variance_power от 1.1 до 1.9
                variance_power = trial.suggest_float('variance_power', 1.1, 1.9)
                
                params = {
                    'iterations': trial.suggest_int('iterations', 100, 1000),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'depth': trial.suggest_int('depth', 4, 10),
                    'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 10),
                    'bagging_temperature': trial.suggest_float('bagging_temperature', 0, 1),
                    'random_seed': 42,
                    # Здесь формируем строку loss_function с текущим variance_power
                    'loss_function': f"Tweedie:variance_power={variance_power}"
                }
                reg = CatBoostRegressor(**params, verbose=False)

            elif model_key == 'HistGradientBoostingRegressor':
                params = {
                    'max_iter': trial.suggest_int('max_iter', 50, 300),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'max_depth': trial.suggest_int('max_depth', 3, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 20),
                    'l2_regularization': trial.suggest_float('l2_regularization', 0, 1)
                }
                reg = HistGradientBoostingRegressor(**params)

            elif model_key == 'ExtraTreesRegressor':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 300),
                    'max_depth': trial.suggest_int('max_depth', 3, 20),
                    'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
                    'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
                }
                reg = ExtraTreesRegressor(**params)

            # Обучаем на train и проверяем R2 на valid
            reg.fit(X_train, y_train)
            y_pred = reg.predict(X_valid)
            return r2_score(y_valid, y_pred)

        # Запускаем оптимизацию Optuna
        study = optuna.create_study(direction='maximize')
        study.optimize(objective, n_trials=n_trials)

        # Формируем финальную модель с лучшими гиперпараметрами
        best_params = study.best_params

        if model_key == 'XGB':
            final_model = XGBRegressor(**best_params)
        
        elif model_key == 'XGB_Tweedie':
            final_model = XGBRegressor(**best_params, objective='reg:tweedie')

        elif model_key == 'RandomForest':
            final_model = RandomForestRegressor(**best_params)

        elif model_key == 'GradientBoosting':
            final_model = GradientBoostingRegressor(**best_params)

        elif model_key == 'CatBoost':
            final_model = CatBoostRegressor(**best_params, verbose=False)

        elif model_key == 'CatBoost_Tweedie':
            # Извлекаем optimal variance_power из best_params
            vp = best_params.pop('variance_power')
            loss_str = f"Tweedie:variance_power={vp}"
            final_model = CatBoostRegressor(**best_params, loss_function=loss_str, verbose=False)

        elif model_key == 'HistGradientBoostingRegressor':
            final_model = HistGradientBoostingRegressor(**best_params)

        elif model_key == 'ExtraTreesRegressor':
            final_model = ExtraTreesRegressor(**best_params)

        # Обучаем финальную модель на полном тренировочном наборе
        final_model.fit(X_train_full, y_train_full)

        # Сохраняем обученную модель в словарь trained_models
        trained_models[model_key] = final_model

        # Оцениваем финальную модель на тестовом наборе
        y_test_pred = final_model.predict(X_test)
        test_r2 = r2_score(y_test, y_test_pred)
        test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
        test_mae = mean_absolute_error(y_test, y_test_pred)

        # Сохраняем метрики в список results
        results.append({
            'Model': model_key,
            'R2': round(test_r2, 4),
            'RMSE': round(test_rmse, 4),
            'MAE': round(test_mae, 4),
            'Tuned': True
        })

    # Превращаем список результатов в DataFrame
    results_tuned = pd.DataFrame(results)

    # Возвращаем две структуры: DataFrame и словарь обученных моделей
    return results_tuned, trained_models

# %%
results_tuned, trained_models = optuna_tuning(models)
# Out:
# [I 2025-06-02 18:46:53,150] A new study created in memory with name: no-name-6e75f7d1-bbe3-489a-b29a-f5bad37e8da6
# [I 2025-06-02 18:46:54,788] Trial 0 finished with value: 0.2719148930768437 and parameters: {'n_estimators': 254, 'max_depth': 10, 'learning_rate': 0.1612355692370409, 'subsample': 0.7147918243831661, 'colsample_bytree': 0.9499110414587895, 'gamma': 4.424885787710149, 'min_child_weight': 3}. Best is trial 0 with value: 0.2719148930768437.
# [I 2025-06-02 18:46:55,105] Trial 1 finished with value: 0.35786846314195864 and parameters: {'n_estimators': 72, 'max_depth': 8, 'learning_rate': 0.09428393804591605, 'subsample': 0.6322868621780102, 'colsample_bytree': 0.769211785062226, 'gamma': 3.3077642757041685, 'min_child_weight': 1}. Best is trial 1 with value: 0.35786846314195864.
# [I 2025-06-02 18:46:56,349] Trial 2 finished with value: 0.277835122530402 and parameters: {'n_estimators': 354, 'max_depth': 10, 'learning_rate': 0.2502653367717173, 'subsample': 0.761981101967064, 'colsample_bytree': 0.8967772861876464, 'gamma': 0.4962375776776978, 'min_child_weight': 1}. Best is trial 1 with value: 0.35786846314195864.
# [I 2025-06-02 18:46:57,348] Trial 3 finished with value: 0.3111422240841678 and parameters: {'n_estimators': 380, 'max_depth': 9, 'learning_rate': 0.18345077674549085, 'subsample': 0.6304284235783904, 'colsample_bytree': 0.7567106554725223, 'gamma': 0.8859563098049245, 'min_child_weight': 4}. Best is trial 1 with value: 0.35786846314195864.
# [I 2025-06-02 18:46:57,982] Trial 4 finished with value: 0.16319630117409145 and parameters: {'n_estimators': 279, 'max_depth': 8, 'learning_rate': 0.2378213726281734, 'subsample': 0.6214157244954099, 'colsample_bytree': 0.9884170063198422, 'gamma': 1.9276512437855469, 'min_child_weight': 9}. Best is trial 1 with value: 0.35786846314195864.
# [I 2025-06-02 18:46:58,535] Trial 5 finished with value: 0.25153773275725 and parameters: {'n_estimators': 296, 'max_depth': 8, 'learning_rate': 0.09352299098212284, 'subsample': 0.5353006992940192, 'colsample_bytree': 0.7967874287634473, 'gamma': 2.8944700527434417, 'min_child_weight': 7}. Best is trial 1 with value: 0.35786846314195864.
# [I 2025-06-02 18:46:59,197] Trial 6 finished with value: 0.375062637764886 and parameters: {'n_estimators': 269, 'max_depth': 10, 'learning_rate': 0.28743691104915586, 'subsample': 0.9334357976104046, 'colsample_bytree': 0.8764772314772916, 'gamma': 2.633955982036102, 'min_child_weight': 2}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:46:59,447] Trial 7 finished with value: 0.16911858019037418 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.27268877573132494, 'subsample': 0.5707706103757658, 'colsample_bytree': 0.6178667673485105, 'gamma': 3.302617077904503, 'min_child_weight': 2}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:00,192] Trial 8 finished with value: 0.11915037747384094 and parameters: {'n_estimators': 377, 'max_depth': 7, 'learning_rate': 0.2998008713450881, 'subsample': 0.6796743451145453, 'colsample_bytree': 0.9368194044931804, 'gamma': 2.056517805992, 'min_child_weight': 5}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:01,179] Trial 9 finished with value: 0.31689839963439703 and parameters: {'n_estimators': 376, 'max_depth': 10, 'learning_rate': 0.04915022917256201, 'subsample': 0.5881525962121086, 'colsample_bytree': 0.5122753402859326, 'gamma': 0.48184637666385477, 'min_child_weight': 4}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:01,422] Trial 10 finished with value: 0.3056252421540643 and parameters: {'n_estimators': 158, 'max_depth': 5, 'learning_rate': 0.1958728866401687, 'subsample': 0.9661308751712304, 'colsample_bytree': 0.8523421804462947, 'gamma': 4.967396611391141, 'min_child_weight': 7}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:01,629] Trial 11 finished with value: 0.3561173362938286 and parameters: {'n_estimators': 71, 'max_depth': 6, 'learning_rate': 0.10544759267964317, 'subsample': 0.8622302806039359, 'colsample_bytree': 0.6758317609296138, 'gamma': 3.4525425100614697, 'min_child_weight': 1}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:05,040] Trial 12 finished with value: 0.3406575071201683 and parameters: {'n_estimators': 484, 'max_depth': 8, 'learning_rate': 0.022063438242004768, 'subsample': 0.9818030516421901, 'colsample_bytree': 0.8279554765482623, 'gamma': 3.9082186823733784, 'min_child_weight': 2}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:05,414] Trial 13 finished with value: 0.3027350540097389 and parameters: {'n_estimators': 76, 'max_depth': 9, 'learning_rate': 0.11620046296448383, 'subsample': 0.8224897503151238, 'colsample_bytree': 0.7040172769626882, 'gamma': 2.3973934159607704, 'min_child_weight': 1}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:05,860] Trial 14 finished with value: 0.34393321795615517 and parameters: {'n_estimators': 181, 'max_depth': 6, 'learning_rate': 0.06888290449303966, 'subsample': 0.8975963458762467, 'colsample_bytree': 0.8669352258147527, 'gamma': 1.4903185352029433, 'min_child_weight': 3}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:06,218] Trial 15 finished with value: 0.26478035286391144 and parameters: {'n_estimators': 153, 'max_depth': 9, 'learning_rate': 0.14009293945766887, 'subsample': 0.7828239505395571, 'colsample_bytree': 0.7656630523885095, 'gamma': 2.7660456759342216, 'min_child_weight': 10}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:06,843] Trial 16 finished with value: 0.21393888184149001 and parameters: {'n_estimators': 499, 'max_depth': 4, 'learning_rate': 0.22766637479898894, 'subsample': 0.5050924099857561, 'colsample_bytree': 0.6308291793296193, 'gamma': 3.9163403587469867, 'min_child_weight': 3}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:07,321] Trial 17 finished with value: 0.3523348092419758 and parameters: {'n_estimators': 218, 'max_depth': 7, 'learning_rate': 0.1399649339121463, 'subsample': 0.9177993823307037, 'colsample_bytree': 0.7124587218910912, 'gamma': 1.6163303545628067, 'min_child_weight': 6}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:07,874] Trial 18 finished with value: 0.24556599026929393 and parameters: {'n_estimators': 110, 'max_depth': 9, 'learning_rate': 0.206501510593663, 'subsample': 0.680115449530029, 'colsample_bytree': 0.8147379045768862, 'gamma': 3.2244309388238905, 'min_child_weight': 2}. Best is trial 6 with value: 0.375062637764886.
# [I 2025-06-02 18:47:18,510] Trial 19 finished with value: 0.38980637139912677 and parameters: {'n_estimators': 453, 'max_depth': 8, 'learning_rate': 0.01027231278324281, 'subsample': 0.820827929267429, 'colsample_bytree': 0.9063073299918615, 'gamma': 3.9083709276796723, 'min_child_weight': 5}. Best is trial 19 with value: 0.38980637139912677.
# [I 2025-06-02 18:47:20,073] Trial 20 finished with value: 0.37176471731635685 and parameters: {'n_estimators': 438, 'max_depth': 10, 'learning_rate': 0.018497994843486854, 'subsample': 0.8290761450827906, 'colsample_bytree': 0.9133915643973514, 'gamma': 4.178977138199437, 'min_child_weight': 6}. Best is trial 19 with value: 0.38980637139912677.
# [I 2025-06-02 18:47:21,954] Trial 21 finished with value: 0.3827987862854958 and parameters: {'n_estimators': 445, 'max_depth': 10, 'learning_rate': 0.010660618601149419, 'subsample': 0.823246284953674, 'colsample_bytree': 0.9054320345686627, 'gamma': 4.373649478726976, 'min_child_weight': 6}. Best is trial 19 with value: 0.38980637139912677.
# [I 2025-06-02 18:47:23,228] Trial 22 finished with value: 0.3691564167819519 and parameters: {'n_estimators': 433, 'max_depth': 9, 'learning_rate': 0.04698240377135975, 'subsample': 0.9107713314429642, 'colsample_bytree': 0.9898843131145191, 'gamma': 4.961160207815874, 'min_child_weight': 8}. Best is trial 19 with value: 0.38980637139912677.
# [I 2025-06-02 18:47:25,007] Trial 23 finished with value: 0.38080367723784725 and parameters: {'n_estimators': 438, 'max_depth': 10, 'learning_rate': 0.01251931784610663, 'subsample': 0.8142839624135619, 'colsample_bytree': 0.8904850718062289, 'gamma': 4.404016881673313, 'min_child_weight': 5}. Best is trial 19 with value: 0.38980637139912677.
# [I 2025-06-02 18:47:26,171] Trial 24 finished with value: 0.3914217157278054 and parameters: {'n_estimators': 442, 'max_depth': 7, 'learning_rate': 0.010876647452762456, 'subsample': 0.8133111714294498, 'colsample_bytree': 0.9461834616898149, 'gamma': 4.65153513832202, 'min_child_weight': 5}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:27,136] Trial 25 finished with value: 0.3550883366359403 and parameters: {'n_estimators': 468, 'max_depth': 7, 'learning_rate': 0.04475192549541691, 'subsample': 0.8629012201617927, 'colsample_bytree': 0.9436766226042985, 'gamma': 4.623171479626594, 'min_child_weight': 7}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:27,652] Trial 26 finished with value: 0.32816046472437266 and parameters: {'n_estimators': 341, 'max_depth': 5, 'learning_rate': 0.06729961901929278, 'subsample': 0.7299371777517115, 'colsample_bytree': 0.9752896816908928, 'gamma': 3.9379257637262404, 'min_child_weight': 5}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:28,436] Trial 27 finished with value: 0.3539211508773532 and parameters: {'n_estimators': 413, 'max_depth': 6, 'learning_rate': 0.03347487327392661, 'subsample': 0.7878433637089184, 'colsample_bytree': 0.9187790851879731, 'gamma': 4.674413540256322, 'min_child_weight': 6}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:29,219] Trial 28 finished with value: 0.30628854897969016 and parameters: {'n_estimators': 412, 'max_depth': 7, 'learning_rate': 0.07072472821627136, 'subsample': 0.8554044569960267, 'colsample_bytree': 0.8279971933145662, 'gamma': 3.892779509893834, 'min_child_weight': 4}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:30,138] Trial 29 finished with value: 0.38435485653245127 and parameters: {'n_estimators': 338, 'max_depth': 8, 'learning_rate': 0.01129710208532458, 'subsample': 0.724239982244615, 'colsample_bytree': 0.9496155007263551, 'gamma': 4.339526286443645, 'min_child_weight': 8}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:30,842] Trial 30 finished with value: 0.3280436764013617 and parameters: {'n_estimators': 325, 'max_depth': 8, 'learning_rate': 0.059779701990270995, 'subsample': 0.7012439781864734, 'colsample_bytree': 0.9574560023749914, 'gamma': 3.5549701496919712, 'min_child_weight': 8}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:32,681] Trial 31 finished with value: 0.3784670349522514 and parameters: {'n_estimators': 462, 'max_depth': 7, 'learning_rate': 0.012089464108976669, 'subsample': 0.7489743454294416, 'colsample_bytree': 0.9385184107396056, 'gamma': 4.357893976290906, 'min_child_weight': 8}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:33,806] Trial 32 finished with value: 0.35837709259923334 and parameters: {'n_estimators': 406, 'max_depth': 8, 'learning_rate': 0.03317829385004084, 'subsample': 0.7839749371172569, 'colsample_bytree': 0.9998282038482119, 'gamma': 4.607361558022192, 'min_child_weight': 10}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:35,215] Trial 33 finished with value: 0.3468381372869843 and parameters: {'n_estimators': 459, 'max_depth': 9, 'learning_rate': 0.029841167083395573, 'subsample': 0.7373483039902213, 'colsample_bytree': 0.8967008842753744, 'gamma': 4.145303751814372, 'min_child_weight': 6}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:36,531] Trial 34 finished with value: 0.31559554793118516 and parameters: {'n_estimators': 233, 'max_depth': 6, 'learning_rate': 0.08497230854956993, 'subsample': 0.708217973517497, 'colsample_bytree': 0.9664604223526411, 'gamma': 3.736176131695791, 'min_child_weight': 5}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:37,492] Trial 35 finished with value: 0.3350518207076346 and parameters: {'n_estimators': 358, 'max_depth': 8, 'learning_rate': 0.039760203113731046, 'subsample': 0.766697396672863, 'colsample_bytree': 0.8443877291507229, 'gamma': 4.819510156779465, 'min_child_weight': 4}. Best is trial 24 with value: 0.3914217157278054.
# [I 2025-06-02 18:47:38,474] Trial 36 finished with value: 0.39164144210227303 and parameters: {'n_estimators': 399, 'max_depth': 8, 'learning_rate': 0.012245570138728299, 'subsample': 0.8079057605552229, 'colsample_bytree': 0.7891571607119259, 'gamma': 0.00422589271747853, 'min_child_weight': 9}. Best is trial 36 with value: 0.39164144210227303.
# [I 2025-06-02 18:47:39,382] Trial 37 finished with value: 0.3368588584552952 and parameters: {'n_estimators': 402, 'max_depth': 8, 'learning_rate': 0.054075622708940924, 'subsample': 0.8836021345448432, 'colsample_bytree': 0.7863690946714762, 'gamma': 0.21882420427848315, 'min_child_weight': 9}. Best is trial 36 with value: 0.39164144210227303.
# [I 2025-06-02 18:47:40,018] Trial 38 finished with value: 0.28613127486919754 and parameters: {'n_estimators': 316, 'max_depth': 7, 'learning_rate': 0.07581115342899658, 'subsample': 0.7988082364407013, 'colsample_bytree': 0.7363426042321479, 'gamma': 0.8751158526456393, 'min_child_weight': 9}. Best is trial 36 with value: 0.39164144210227303.
# [I 2025-06-02 18:47:40,744] Trial 39 finished with value: 0.2541000662192169 and parameters: {'n_estimators': 353, 'max_depth': 7, 'learning_rate': 0.1613587315102658, 'subsample': 0.6605748685044553, 'colsample_bytree': 0.8720885696156231, 'gamma': 3.0384974461404495, 'min_child_weight': 7}. Best is trial 36 with value: 0.39164144210227303.
# [I 2025-06-02 18:47:42,198] Trial 40 finished with value: 0.39308585480317004 and parameters: {'n_estimators': 394, 'max_depth': 8, 'learning_rate': 0.027935992687388243, 'subsample': 0.9511397655004734, 'colsample_bytree': 0.9195070070204493, 'gamma': 2.2102685919532745, 'min_child_weight': 10}. Best is trial 40 with value: 0.39308585480317004.
# [I 2025-06-02 18:47:43,813] Trial 41 finished with value: 0.3565180996363625 and parameters: {'n_estimators': 383, 'max_depth': 8, 'learning_rate': 0.028967658882666465, 'subsample': 0.9545170750302215, 'colsample_bytree': 0.9369838263280088, 'gamma': 1.3395636104482262, 'min_child_weight': 10}. Best is trial 40 with value: 0.39308585480317004.
# [I 2025-06-02 18:47:45,112] Trial 42 finished with value: 0.3693163341463773 and parameters: {'n_estimators': 391, 'max_depth': 8, 'learning_rate': 0.024696401679876134, 'subsample': 0.8429756728561434, 'colsample_bytree': 0.9668628195531774, 'gamma': 1.1460088687804109, 'min_child_weight': 9}. Best is trial 40 with value: 0.39308585480317004.
# [I 2025-06-02 18:47:46,754] Trial 43 finished with value: 0.33234565412436423 and parameters: {'n_estimators': 425, 'max_depth': 9, 'learning_rate': 0.0469777773616259, 'subsample': 0.8788174133834357, 'colsample_bytree': 0.920735045839928, 'gamma': 2.291586281529997, 'min_child_weight': 9}. Best is trial 40 with value: 0.39308585480317004.
# [I 2025-06-02 18:47:47,568] Trial 44 finished with value: 0.3941111740493253 and parameters: {'n_estimators': 284, 'max_depth': 8, 'learning_rate': 0.011851452733646638, 'subsample': 0.761924576484152, 'colsample_bytree': 0.8843408087279995, 'gamma': 1.9327312227621667, 'min_child_weight': 10}. Best is trial 44 with value: 0.3941111740493253.
# [I 2025-06-02 18:47:48,109] Trial 45 finished with value: 0.3702193757611997 and parameters: {'n_estimators': 262, 'max_depth': 8, 'learning_rate': 0.0356130191942321, 'subsample': 0.7583546859547482, 'colsample_bytree': 0.7989687496654666, 'gamma': 2.1102542010477725, 'min_child_weight': 10}. Best is trial 44 with value: 0.3941111740493253.
# [I 2025-06-02 18:47:48,990] Trial 46 finished with value: 0.37260713699736636 and parameters: {'n_estimators': 482, 'max_depth': 7, 'learning_rate': 0.05771891119905308, 'subsample': 0.9388092649758447, 'colsample_bytree': 0.8506622409890243, 'gamma': 1.7424973690074292, 'min_child_weight': 10}. Best is trial 44 with value: 0.3941111740493253.
# [I 2025-06-02 18:47:50,274] Trial 47 finished with value: 0.3049004615934855 and parameters: {'n_estimators': 298, 'max_depth': 9, 'learning_rate': 0.09128198030731555, 'subsample': 0.9846374614150266, 'colsample_bytree': 0.8826594295117839, 'gamma': 2.6331451272176603, 'min_child_weight': 9}. Best is trial 44 with value: 0.3941111740493253.
# [I 2025-06-02 18:47:51,528] Trial 48 finished with value: 0.29432498389090933 and parameters: {'n_estimators': 486, 'max_depth': 7, 'learning_rate': 0.11404197801026027, 'subsample': 0.8040708894723565, 'colsample_bytree': 0.5078486420521116, 'gamma': 0.04184095102335937, 'min_child_weight': 10}. Best is trial 44 with value: 0.3941111740493253.
# [I 2025-06-02 18:47:52,096] Trial 49 finished with value: 0.3559543047574887 and parameters: {'n_estimators': 365, 'max_depth': 5, 'learning_rate': 0.022029053824120407, 'subsample': 0.7683960502310697, 'colsample_bytree': 0.5385972637029584, 'gamma': 0.9345899966442539, 'min_child_weight': 3}. Best is trial 44 with value: 0.3941111740493253.
# [I 2025-06-02 18:47:52,991] A new study created in memory with name: no-name-d8002cd9-c5b4-4485-9dce-ad71a8ac2c6e
# [I 2025-06-02 18:47:53,126] Trial 0 finished with value: 0.3755080366773538 and parameters: {'n_estimators': 118, 'max_depth': 3, 'learning_rate': 0.22221638792750578, 'subsample': 0.753420876322626, 'colsample_bytree': 0.9684684835468933, 'gamma': 2.084039232021139, 'min_child_weight': 4, 'tweedie_variance_power': 1.7841962263402595}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:53,612] Trial 1 finished with value: -3.3832142633788074 and parameters: {'n_estimators': 367, 'max_depth': 9, 'learning_rate': 0.28899729828445164, 'subsample': 0.5101794490658231, 'colsample_bytree': 0.9372101475205312, 'gamma': 2.934330635204322, 'min_child_weight': 3, 'tweedie_variance_power': 1.5124984839063653}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:54,053] Trial 2 finished with value: 0.08369199013988415 and parameters: {'n_estimators': 408, 'max_depth': 4, 'learning_rate': 0.24562435586327522, 'subsample': 0.7118556724767067, 'colsample_bytree': 0.8477828214576136, 'gamma': 0.09586112668569347, 'min_child_weight': 5, 'tweedie_variance_power': 1.1409054702207264}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:54,401] Trial 3 finished with value: 0.32746664837281725 and parameters: {'n_estimators': 281, 'max_depth': 6, 'learning_rate': 0.06558013128507868, 'subsample': 0.7422839445288405, 'colsample_bytree': 0.6029085727075965, 'gamma': 4.674615434255729, 'min_child_weight': 7, 'tweedie_variance_power': 1.4299273758948396}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:54,518] Trial 4 finished with value: 0.3652508077537103 and parameters: {'n_estimators': 56, 'max_depth': 6, 'learning_rate': 0.06552043710185187, 'subsample': 0.7945841133181677, 'colsample_bytree': 0.7340479394534185, 'gamma': 3.0407131288209537, 'min_child_weight': 2, 'tweedie_variance_power': 1.724660708572324}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:54,693] Trial 5 finished with value: 0.30912231833630754 and parameters: {'n_estimators': 162, 'max_depth': 3, 'learning_rate': 0.1217441644862993, 'subsample': 0.6731767205256731, 'colsample_bytree': 0.9576012349682299, 'gamma': 3.4640213395014485, 'min_child_weight': 2, 'tweedie_variance_power': 1.1493405176772566}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:55,216] Trial 6 finished with value: 0.3577721871059556 and parameters: {'n_estimators': 402, 'max_depth': 5, 'learning_rate': 0.017712015612250893, 'subsample': 0.7960764922624326, 'colsample_bytree': 0.6892881821777777, 'gamma': 0.8112783942046076, 'min_child_weight': 3, 'tweedie_variance_power': 1.461744110663811}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:55,698] Trial 7 finished with value: 0.344162213344231 and parameters: {'n_estimators': 187, 'max_depth': 7, 'learning_rate': 0.022371579848378585, 'subsample': 0.7734715940338028, 'colsample_bytree': 0.7112774465949456, 'gamma': 1.521954827664741, 'min_child_weight': 1, 'tweedie_variance_power': 1.7398573221982119}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:56,045] Trial 8 finished with value: 0.28043347668282737 and parameters: {'n_estimators': 451, 'max_depth': 3, 'learning_rate': 0.22224939740751998, 'subsample': 0.8171711778591081, 'colsample_bytree': 0.6527735331838926, 'gamma': 1.4523122204937438, 'min_child_weight': 7, 'tweedie_variance_power': 1.3703064905937161}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:57,537] Trial 9 finished with value: 0.2645666475370356 and parameters: {'n_estimators': 484, 'max_depth': 9, 'learning_rate': 0.06462765914171967, 'subsample': 0.5409870819751033, 'colsample_bytree': 0.9743135975603703, 'gamma': 0.09991314353373137, 'min_child_weight': 6, 'tweedie_variance_power': 1.5304706989220398}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:57,641] Trial 10 finished with value: 0.3506563431123346 and parameters: {'n_estimators': 86, 'max_depth': 8, 'learning_rate': 0.18001126912726773, 'subsample': 0.9922598390502758, 'colsample_bytree': 0.5057203919749673, 'gamma': 2.1426904536909634, 'min_child_weight': 10, 'tweedie_variance_power': 1.8715680743411074}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:57,749] Trial 11 finished with value: 0.36337074096895383 and parameters: {'n_estimators': 71, 'max_depth': 5, 'learning_rate': 0.14102815771229082, 'subsample': 0.9008760620603411, 'colsample_bytree': 0.7958562604889097, 'gamma': 3.583980185159573, 'min_child_weight': 4, 'tweedie_variance_power': 1.700693872448514}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:57,930] Trial 12 finished with value: 0.3704540202959341 and parameters: {'n_estimators': 157, 'max_depth': 7, 'learning_rate': 0.18920586891938063, 'subsample': 0.6255885512764209, 'colsample_bytree': 0.861448582804545, 'gamma': 2.3793202476971165, 'min_child_weight': 1, 'tweedie_variance_power': 1.8935783973776867}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:58,149] Trial 13 finished with value: 0.29613621959587 and parameters: {'n_estimators': 177, 'max_depth': 10, 'learning_rate': 0.1942927377584595, 'subsample': 0.6058345298748322, 'colsample_bytree': 0.8713475807761712, 'gamma': 2.163096442416632, 'min_child_weight': 1, 'tweedie_variance_power': 1.8826822723328402}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:58,450] Trial 14 finished with value: 0.25517473190214657 and parameters: {'n_estimators': 245, 'max_depth': 7, 'learning_rate': 0.26995471613233274, 'subsample': 0.6333330175412292, 'colsample_bytree': 0.8953209371430666, 'gamma': 1.941327157367359, 'min_child_weight': 9, 'tweedie_variance_power': 1.7971505128174559}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:58,641] Trial 15 finished with value: 0.28305833746372155 and parameters: {'n_estimators': 130, 'max_depth': 5, 'learning_rate': 0.21166774139809674, 'subsample': 0.5743261008534339, 'colsample_bytree': 0.7987791601791228, 'gamma': 4.418242998103656, 'min_child_weight': 4, 'tweedie_variance_power': 1.58732639942729}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:58,924] Trial 16 finished with value: 0.2665037227460635 and parameters: {'n_estimators': 256, 'max_depth': 8, 'learning_rate': 0.16289034719092255, 'subsample': 0.8704820585630316, 'colsample_bytree': 0.9204437077594196, 'gamma': 1.1187848508572769, 'min_child_weight': 5, 'tweedie_variance_power': 1.6508889141784335}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:59,198] Trial 17 finished with value: 0.28809754244604824 and parameters: {'n_estimators': 309, 'max_depth': 4, 'learning_rate': 0.24572575131130575, 'subsample': 0.6947142876959884, 'colsample_bytree': 0.8195836440566041, 'gamma': 2.7370244543575124, 'min_child_weight': 3, 'tweedie_variance_power': 1.8161568982465774}. Best is trial 0 with value: 0.3755080366773538.
# [I 2025-06-02 18:47:59,556] Trial 18 finished with value: 0.3976923016465984 and parameters: {'n_estimators': 122, 'max_depth': 8, 'learning_rate': 0.11356409487257105, 'subsample': 0.639280816228685, 'colsample_bytree': 0.9957710359620336, 'gamma': 3.740202590478913, 'min_child_weight': 1, 'tweedie_variance_power': 1.2408738143353875}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:47:59,897] Trial 19 finished with value: 0.3139053686308726 and parameters: {'n_estimators': 113, 'max_depth': 10, 'learning_rate': 0.10960500237965312, 'subsample': 0.6543553017047232, 'colsample_bytree': 0.9840662829710852, 'gamma': 4.092349850654576, 'min_child_weight': 8, 'tweedie_variance_power': 1.2977691143210341}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:00,226] Trial 20 finished with value: 0.3285483034641381 and parameters: {'n_estimators': 217, 'max_depth': 8, 'learning_rate': 0.10569237484369322, 'subsample': 0.8623232989623201, 'colsample_bytree': 0.9954743304059871, 'gamma': 3.872669502415076, 'min_child_weight': 4, 'tweedie_variance_power': 1.3329538518720938}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:00,596] Trial 21 finished with value: 0.31717413462591404 and parameters: {'n_estimators': 134, 'max_depth': 7, 'learning_rate': 0.1558278870876737, 'subsample': 0.5972589395568716, 'colsample_bytree': 0.9035328926881787, 'gamma': 2.466916682641905, 'min_child_weight': 1, 'tweedie_variance_power': 1.2518981770262634}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:00,784] Trial 22 finished with value: 0.326173953918089 and parameters: {'n_estimators': 206, 'max_depth': 9, 'learning_rate': 0.1937100274819682, 'subsample': 0.7288306742396605, 'colsample_bytree': 0.926333416307303, 'gamma': 3.292989599667938, 'min_child_weight': 2, 'tweedie_variance_power': 1.8992006065807048}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:00,941] Trial 23 finished with value: 0.3381302810165083 and parameters: {'n_estimators': 105, 'max_depth': 6, 'learning_rate': 0.22445894495391713, 'subsample': 0.5643015928307207, 'colsample_bytree': 0.8548722164604571, 'gamma': 2.507993693323283, 'min_child_weight': 1, 'tweedie_variance_power': 1.797645047111652}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:01,205] Trial 24 finished with value: 0.31992510953639075 and parameters: {'n_estimators': 155, 'max_depth': 8, 'learning_rate': 0.13334474533237417, 'subsample': 0.6267940831421324, 'colsample_bytree': 0.9948387407985589, 'gamma': 4.900888711132011, 'min_child_weight': 2, 'tweedie_variance_power': 1.6214904630032765}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:01,438] Trial 25 finished with value: 0.31689295301103126 and parameters: {'n_estimators': 57, 'max_depth': 7, 'learning_rate': 0.08400711691115904, 'subsample': 0.6784626069538929, 'colsample_bytree': 0.7662938001361458, 'gamma': 1.8866689864840178, 'min_child_weight': 3, 'tweedie_variance_power': 1.235179831551297}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:01,617] Trial 26 finished with value: 0.37012157681957614 and parameters: {'n_estimators': 99, 'max_depth': 4, 'learning_rate': 0.17819716553650936, 'subsample': 0.5147919963260748, 'colsample_bytree': 0.9449675933111873, 'gamma': 0.8358049967638683, 'min_child_weight': 6, 'tweedie_variance_power': 1.8155028339926866}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:01,939] Trial 27 finished with value: 0.2960923087507442 and parameters: {'n_estimators': 314, 'max_depth': 6, 'learning_rate': 0.24764323120908105, 'subsample': 0.7093057934276714, 'colsample_bytree': 0.8831014912691048, 'gamma': 2.4613828350041604, 'min_child_weight': 2, 'tweedie_variance_power': 1.5682761387225783}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:02,154] Trial 28 finished with value: 0.3596954608698719 and parameters: {'n_estimators': 148, 'max_depth': 9, 'learning_rate': 0.2063051471705244, 'subsample': 0.7611558985489812, 'colsample_bytree': 0.8308563894587392, 'gamma': 3.8659903310546087, 'min_child_weight': 1, 'tweedie_variance_power': 1.4321028222090264}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:02,420] Trial 29 finished with value: -0.020946866480308524 and parameters: {'n_estimators': 224, 'max_depth': 9, 'learning_rate': 0.2906430203534454, 'subsample': 0.5031425285214414, 'colsample_bytree': 0.9483864919192603, 'gamma': 2.963760918110614, 'min_child_weight': 4, 'tweedie_variance_power': 1.6768538289991568}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:02,827] Trial 30 finished with value: 0.318271564840952 and parameters: {'n_estimators': 123, 'max_depth': 8, 'learning_rate': 0.2684653420198161, 'subsample': 0.6672550759789105, 'colsample_bytree': 0.9275671020036893, 'gamma': 1.6943244396091148, 'min_child_weight': 3, 'tweedie_variance_power': 1.1981197141927047}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:02,972] Trial 31 finished with value: 0.32434920261612454 and parameters: {'n_estimators': 91, 'max_depth': 4, 'learning_rate': 0.17457439539180827, 'subsample': 0.5350523933408315, 'colsample_bytree': 0.9481275638883073, 'gamma': 0.7681786010541307, 'min_child_weight': 6, 'tweedie_variance_power': 1.81598868659844}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:03,101] Trial 32 finished with value: 0.38612642689218546 and parameters: {'n_estimators': 93, 'max_depth': 3, 'learning_rate': 0.144737568703061, 'subsample': 0.5337505414942524, 'colsample_bytree': 0.9626294212876485, 'gamma': 0.6188855201210883, 'min_child_weight': 5, 'tweedie_variance_power': 1.84533656898533}. Best is trial 18 with value: 0.3976923016465984.
# [I 2025-06-02 18:48:03,293] Trial 33 finished with value: 0.411557738668612 and parameters: {'n_estimators': 169, 'max_depth': 3, 'learning_rate': 0.14855509638914866, 'subsample': 0.5824793651481036, 'colsample_bytree': 0.9692224616963983, 'gamma': 0.3488163519728211, 'min_child_weight': 5, 'tweedie_variance_power': 1.7574369256300792}. Best is trial 33 with value: 0.411557738668612.
# [I 2025-06-02 18:48:03,502] Trial 34 finished with value: 0.38809868652745927 and parameters: {'n_estimators': 190, 'max_depth': 3, 'learning_rate': 0.14274207328964938, 'subsample': 0.570275783714376, 'colsample_bytree': 0.9992271059880755, 'gamma': 0.4547384947617626, 'min_child_weight': 5, 'tweedie_variance_power': 1.7631787137615178}. Best is trial 33 with value: 0.411557738668612.
# [I 2025-06-02 18:48:03,745] Trial 35 finished with value: 0.33733412097322835 and parameters: {'n_estimators': 194, 'max_depth': 3, 'learning_rate': 0.14347963199376823, 'subsample': 0.5549300363717843, 'colsample_bytree': 0.97147498264779, 'gamma': 0.5178799062730565, 'min_child_weight': 5, 'tweedie_variance_power': 1.761604894116684}. Best is trial 33 with value: 0.411557738668612.
# [I 2025-06-02 18:48:04,057] Trial 36 finished with value: 0.3186577042013762 and parameters: {'n_estimators': 298, 'max_depth': 3, 'learning_rate': 0.09071361267097655, 'subsample': 0.5961198668335396, 'colsample_bytree': 0.9656098277014571, 'gamma': 0.2826675994449695, 'min_child_weight': 7, 'tweedie_variance_power': 1.116526882355415}. Best is trial 33 with value: 0.411557738668612.
# [I 2025-06-02 18:48:04,311] Trial 37 finished with value: 0.38148178837724434 and parameters: {'n_estimators': 238, 'max_depth': 3, 'learning_rate': 0.1298326032627408, 'subsample': 0.5790760395677947, 'colsample_bytree': 0.9961525339648285, 'gamma': 0.43846184672895505, 'min_child_weight': 5, 'tweedie_variance_power': 1.7134873318731703}. Best is trial 33 with value: 0.411557738668612.
# [I 2025-06-02 18:48:04,540] Trial 38 finished with value: 0.2489657752562725 and parameters: {'n_estimators': 179, 'max_depth': 4, 'learning_rate': 0.11251859392959518, 'subsample': 0.5273063366364176, 'colsample_bytree': 0.9050236750663341, 'gamma': 1.1854359880463892, 'min_child_weight': 6, 'tweedie_variance_power': 1.8454929124301833}. Best is trial 33 with value: 0.411557738668612.
# [I 2025-06-02 18:48:05,027] Trial 39 finished with value: 0.3674600125406797 and parameters: {'n_estimators': 350, 'max_depth': 5, 'learning_rate': 0.1596161211704133, 'subsample': 0.6472882101780175, 'colsample_bytree': 0.6040165132293076, 'gamma': 0.08191996641804478, 'min_child_weight': 7, 'tweedie_variance_power': 1.749763001054363}. Best is trial 33 with value: 0.411557738668612.
# [I 2025-06-02 18:48:05,140] Trial 40 finished with value: 0.43985842033510847 and parameters: {'n_estimators': 69, 'max_depth': 3, 'learning_rate': 0.0856614789110155, 'subsample': 0.5554323135912748, 'colsample_bytree': 0.9585614286180191, 'gamma': 0.5788942917097455, 'min_child_weight': 8, 'tweedie_variance_power': 1.5018181067900613}. Best is trial 40 with value: 0.43985842033510847.
# [I 2025-06-02 18:48:05,232] Trial 41 finished with value: 0.3777912208901242 and parameters: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.047118334820067706, 'subsample': 0.5482040534482092, 'colsample_bytree': 0.9635338235348629, 'gamma': 0.6286290329793764, 'min_child_weight': 8, 'tweedie_variance_power': 1.5223909824735578}. Best is trial 40 with value: 0.43985842033510847.
# [I 2025-06-02 18:48:05,339] Trial 42 finished with value: 0.389270743957856 and parameters: {'n_estimators': 72, 'max_depth': 3, 'learning_rate': 0.08951934820418533, 'subsample': 0.6035138018099516, 'colsample_bytree': 0.9287245063555477, 'gamma': 1.1277691249544435, 'min_child_weight': 10, 'tweedie_variance_power': 1.4838616831344127}. Best is trial 40 with value: 0.43985842033510847.
# [I 2025-06-02 18:48:05,477] Trial 43 finished with value: 0.42331152796980387 and parameters: {'n_estimators': 74, 'max_depth': 4, 'learning_rate': 0.08859593819403917, 'subsample': 0.6066671390402707, 'colsample_bytree': 0.9251133098915411, 'gamma': 1.103880089310508, 'min_child_weight': 10, 'tweedie_variance_power': 1.3931171985477673}. Best is trial 40 with value: 0.43985842033510847.
# [I 2025-06-02 18:48:05,606] Trial 44 finished with value: 0.4172649859849793 and parameters: {'n_estimators': 74, 'max_depth': 4, 'learning_rate': 0.08615675900700862, 'subsample': 0.6068474617425276, 'colsample_bytree': 0.920337395628743, 'gamma': 1.13795019512321, 'min_child_weight': 10, 'tweedie_variance_power': 1.3799727976993834}. Best is trial 40 with value: 0.43985842033510847.
# [I 2025-06-02 18:48:05,753] Trial 45 finished with value: 0.39131688474058446 and parameters: {'n_estimators': 76, 'max_depth': 4, 'learning_rate': 0.04491808299834053, 'subsample': 0.6133447999324368, 'colsample_bytree': 0.9095460989946182, 'gamma': 0.892378128642651, 'min_child_weight': 9, 'tweedie_variance_power': 1.333609399219384}. Best is trial 40 with value: 0.43985842033510847.
# [I 2025-06-02 18:48:06,004] Trial 46 finished with value: 0.3638979918796237 and parameters: {'n_estimators': 138, 'max_depth': 5, 'learning_rate': 0.07263292958805026, 'subsample': 0.5841401886919666, 'colsample_bytree': 0.8907846075245338, 'gamma': 1.2443724992288363, 'min_child_weight': 9, 'tweedie_variance_power': 1.3886513400322078}. Best is trial 40 with value: 0.43985842033510847.
# [I 2025-06-02 18:48:06,148] Trial 47 finished with value: 0.3599181412676624 and parameters: {'n_estimators': 110, 'max_depth': 4, 'learning_rate': 0.0468227798175617, 'subsample': 0.6412786345509126, 'colsample_bytree': 0.5325210693668175, 'gamma': 0.3041388607582399, 'min_child_weight': 10, 'tweedie_variance_power': 1.4324799381751205}. Best is trial 40 with value: 0.43985842033510847.
# [I 2025-06-02 18:48:06,249] Trial 48 finished with value: 0.3393547866512263 and parameters: {'n_estimators': 50, 'max_depth': 4, 'learning_rate': 0.09673977863953276, 'subsample': 0.6185262294134733, 'colsample_bytree': 0.8735527159215891, 'gamma': 1.4676762719127954, 'min_child_weight': 8, 'tweedie_variance_power': 1.398157778928217}. Best is trial 40 with value: 0.43985842033510847.
# [I 2025-06-02 18:48:06,462] Trial 49 finished with value: 0.3533264099839464 and parameters: {'n_estimators': 78, 'max_depth': 6, 'learning_rate': 0.06890610000638793, 'subsample': 0.6840974293150588, 'colsample_bytree': 0.6734341735231196, 'gamma': 0.025000185551056764, 'min_child_weight': 9, 'tweedie_variance_power': 1.1858110629319247}. Best is trial 40 with value: 0.43985842033510847.
# [I 2025-06-02 18:48:06,557] A new study created in memory with name: no-name-5b0f8129-c8f2-4f50-90a0-30849b720d19
# [I 2025-06-02 18:48:07,621] Trial 0 finished with value: 0.4267810976555714 and parameters: {'n_estimators': 105, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:07,979] Trial 1 finished with value: 0.41013692010498204 and parameters: {'n_estimators': 75, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:08,206] Trial 2 finished with value: 0.15156654372504852 and parameters: {'n_estimators': 257, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:08,631] Trial 3 finished with value: 0.32338264010507634 and parameters: {'n_estimators': 286, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:08,751] Trial 4 finished with value: 0.3137041827710374 and parameters: {'n_estimators': 90, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:08,992] Trial 5 finished with value: 0.3075314302946739 and parameters: {'n_estimators': 175, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:09,221] Trial 6 finished with value: 0.3351733365101788 and parameters: {'n_estimators': 151, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:09,338] Trial 7 finished with value: 0.32364405846674105 and parameters: {'n_estimators': 84, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:11,168] Trial 8 finished with value: 0.4124612625570838 and parameters: {'n_estimators': 206, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:11,405] Trial 9 finished with value: 0.2138715078475918 and parameters: {'n_estimators': 251, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:12,557] Trial 10 finished with value: 0.4043619791374484 and parameters: {'n_estimators': 128, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:14,357] Trial 11 finished with value: 0.4178346354930734 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:16,664] Trial 12 finished with value: 0.4057038543859175 and parameters: {'n_estimators': 209, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:17,844] Trial 13 finished with value: 0.4217601459994671 and parameters: {'n_estimators': 138, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:18,942] Trial 14 finished with value: 0.41583881974427217 and parameters: {'n_estimators': 119, 'max_depth': 19, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:19,461] Trial 15 finished with value: 0.4216436773987351 and parameters: {'n_estimators': 55, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:20,576] Trial 16 finished with value: 0.4054244351100612 and parameters: {'n_estimators': 124, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:22,065] Trial 17 finished with value: 0.4156372623746182 and parameters: {'n_estimators': 147, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:23,334] Trial 18 finished with value: 0.4045281515447121 and parameters: {'n_estimators': 101, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:23,408] Trial 19 finished with value: 0.2717831314118522 and parameters: {'n_estimators': 51, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 0 with value: 0.4267810976555714.
# [I 2025-06-02 18:48:25,018] Trial 20 finished with value: 0.4311407074225827 and parameters: {'n_estimators': 165, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:26,557] Trial 21 finished with value: 0.4193385959429655 and parameters: {'n_estimators': 164, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:28,606] Trial 22 finished with value: 0.42885324064730823 and parameters: {'n_estimators': 184, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:30,759] Trial 23 finished with value: 0.41001277051166185 and parameters: {'n_estimators': 191, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:33,314] Trial 24 finished with value: 0.4224008320315277 and parameters: {'n_estimators': 234, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:35,022] Trial 25 finished with value: 0.42305542132468243 and parameters: {'n_estimators': 180, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:37,884] Trial 26 finished with value: 0.4219709434676595 and parameters: {'n_estimators': 221, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:39,018] Trial 27 finished with value: 0.4182931199515024 and parameters: {'n_estimators': 103, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:39,242] Trial 28 finished with value: 0.3004379610653106 and parameters: {'n_estimators': 175, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:39,527] Trial 29 finished with value: 0.3216138112393018 and parameters: {'n_estimators': 158, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:40,183] Trial 30 finished with value: 0.40665385638897833 and parameters: {'n_estimators': 67, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:42,005] Trial 31 finished with value: 0.4157779919846417 and parameters: {'n_estimators': 189, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:43,590] Trial 32 finished with value: 0.4141683491237885 and parameters: {'n_estimators': 175, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:46,078] Trial 33 finished with value: 0.4080974715675635 and parameters: {'n_estimators': 240, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:48,828] Trial 34 finished with value: 0.4174211770986518 and parameters: {'n_estimators': 290, 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:49,339] Trial 35 finished with value: 0.3305815151388798 and parameters: {'n_estimators': 271, 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:49,626] Trial 36 finished with value: 0.281847576987305 and parameters: {'n_estimators': 184, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:51,670] Trial 37 finished with value: 0.4300686877128913 and parameters: {'n_estimators': 218, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:52,011] Trial 38 finished with value: 0.30978791537579153 and parameters: {'n_estimators': 213, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:53,995] Trial 39 finished with value: 0.4230349395338878 and parameters: {'n_estimators': 225, 'max_depth': 19, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:54,295] Trial 40 finished with value: 0.2718598160160338 and parameters: {'n_estimators': 254, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:55,807] Trial 41 finished with value: 0.4254133170780555 and parameters: {'n_estimators': 163, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 20 with value: 0.4311407074225827.
# [I 2025-06-02 18:48:57,153] Trial 42 finished with value: 0.441178230829811 and parameters: {'n_estimators': 160, 'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 42 with value: 0.441178230829811.
# [I 2025-06-02 18:48:58,349] Trial 43 finished with value: 0.43465416216607244 and parameters: {'n_estimators': 143, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 42 with value: 0.441178230829811.
# ...
# [I 2025-06-02 19:01:37,881] Trial 39 finished with value: 0.36474103111680856 and parameters: {'max_iter': 116, 'learning_rate': 0.07422367151789303, 'max_depth': 9, 'min_samples_leaf': 20, 'l2_regularization': 0.6826766353653518}. Best is trial 32 with value: 0.3912593959179256.
# [I 2025-06-02 19:01:38,288] Trial 40 finished with value: 0.3806565890775482 and parameters: {'max_iter': 144, 'learning_rate': 0.011233015707260392, 'max_depth': 10, 'min_samples_leaf': 17, 'l2_regularization': 0.8090745293154402}. Best is trial 32 with value: 0.3912593959179256.
# [I 2025-06-02 19:01:38,528] Trial 41 finished with value: 0.3839140005138306 and parameters: {'max_iter': 68, 'learning_rate': 0.03207139831431001, 'max_depth': 9, 'min_samples_leaf': 18, 'l2_regularization': 0.9443959005771443}. Best is trial 32 with value: 0.3912593959179256.
# [I 2025-06-02 19:01:38,769] Trial 42 finished with value: 0.3747282062067343 and parameters: {'max_iter': 81, 'learning_rate': 0.029788697268240762, 'max_depth': 8, 'min_samples_leaf': 19, 'l2_regularization': 0.8451459098425845}. Best is trial 32 with value: 0.3912593959179256.
# [I 2025-06-02 19:01:39,003] Trial 43 finished with value: 0.3837426242442138 and parameters: {'max_iter': 51, 'learning_rate': 0.05323496972370073, 'max_depth': 9, 'min_samples_leaf': 15, 'l2_regularization': 0.9163624939359845}. Best is trial 32 with value: 0.3912593959179256.
# [I 2025-06-02 19:01:39,284] Trial 44 finished with value: 0.3873164071053651 and parameters: {'max_iter': 81, 'learning_rate': 0.02291248196840902, 'max_depth': 8, 'min_samples_leaf': 18, 'l2_regularization': 0.4782845150908667}. Best is trial 32 with value: 0.3912593959179256.
# [I 2025-06-02 19:01:39,625] Trial 45 finished with value: 0.3548641700447567 and parameters: {'max_iter': 86, 'learning_rate': 0.05785391924362156, 'max_depth': 8, 'min_samples_leaf': 5, 'l2_regularization': 0.44318366799026665}. Best is trial 32 with value: 0.3912593959179256.
# [I 2025-06-02 19:01:39,887] Trial 46 finished with value: 0.38652871347889417 and parameters: {'max_iter': 101, 'learning_rate': 0.041759224653939886, 'max_depth': 8, 'min_samples_leaf': 20, 'l2_regularization': 0.4744958140090752}. Best is trial 32 with value: 0.3912593959179256.
# [I 2025-06-02 19:01:40,192] Trial 47 finished with value: 0.35726414829696274 and parameters: {'max_iter': 100, 'learning_rate': 0.012490276928841844, 'max_depth': 8, 'min_samples_leaf': 16, 'l2_regularization': 0.4911813418032209}. Best is trial 32 with value: 0.3912593959179256.
# [I 2025-06-02 19:01:40,400] Trial 48 finished with value: 0.35675509342117895 and parameters: {'max_iter': 62, 'learning_rate': 0.1746182444527437, 'max_depth': 8, 'min_samples_leaf': 17, 'l2_regularization': 0.6513877820593351}. Best is trial 32 with value: 0.3912593959179256.
# [I 2025-06-02 19:01:40,753] Trial 49 finished with value: 0.2577993941868073 and parameters: {'max_iter': 119, 'learning_rate': 0.21801918119539138, 'max_depth': 9, 'min_samples_leaf': 13, 'l2_regularization': 0.40382634449770743}. Best is trial 32 with value: 0.3912593959179256.
# [I 2025-06-02 19:01:41,002] A new study created in memory with name: no-name-0eb65ab5-386e-4ac9-b948-56571f3ccf30
# [I 2025-06-02 19:01:41,566] Trial 0 finished with value: 0.37872802608274947 and parameters: {'n_estimators': 261, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:41,758] Trial 1 finished with value: 0.23529008826207642 and parameters: {'n_estimators': 264, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:41,907] Trial 2 finished with value: 0.24197847227338654 and parameters: {'n_estimators': 186, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:42,053] Trial 3 finished with value: 0.1808808561004377 and parameters: {'n_estimators': 245, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:42,103] Trial 4 finished with value: 0.20412765604914662 and parameters: {'n_estimators': 70, 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:42,251] Trial 5 finished with value: 0.19992803867235365 and parameters: {'n_estimators': 226, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:42,405] Trial 6 finished with value: 0.22574118470883586 and parameters: {'n_estimators': 225, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:42,498] Trial 7 finished with value: 0.2746958162389542 and parameters: {'n_estimators': 110, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:42,637] Trial 8 finished with value: 0.2260170668572875 and parameters: {'n_estimators': 208, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:42,776] Trial 9 finished with value: 0.1812759099724478 and parameters: {'n_estimators': 227, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:43,243] Trial 10 finished with value: 0.31968314716157153 and parameters: {'n_estimators': 286, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:43,633] Trial 11 finished with value: 0.2641045046134064 and parameters: {'n_estimators': 298, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:44,019] Trial 12 finished with value: 0.26619204554843434 and parameters: {'n_estimators': 296, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:44,364] Trial 13 finished with value: 0.36343115385332825 and parameters: {'n_estimators': 141, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:44,695] Trial 14 finished with value: 0.3603788111522679 and parameters: {'n_estimators': 142, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:45,044] Trial 15 finished with value: 0.3705282436239149 and parameters: {'n_estimators': 154, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:45,496] Trial 16 finished with value: 0.3748458878714409 and parameters: {'n_estimators': 157, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:45,801] Trial 17 finished with value: 0.3695268774019381 and parameters: {'n_estimators': 106, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:46,308] Trial 18 finished with value: 0.3741562887500014 and parameters: {'n_estimators': 183, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:46,486] Trial 19 finished with value: 0.3748492695433083 and parameters: {'n_estimators': 58, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:46,693] Trial 20 finished with value: 0.3511766875244746 and parameters: {'n_estimators': 58, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 0 with value: 0.37872802608274947.
# [I 2025-06-02 19:01:46,952] Trial 21 finished with value: 0.39307666658643026 and parameters: {'n_estimators': 91, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:47,202] Trial 22 finished with value: 0.38439631175600675 and parameters: {'n_estimators': 91, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:47,449] Trial 23 finished with value: 0.370353824847269 and parameters: {'n_estimators': 88, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:47,763] Trial 24 finished with value: 0.37690797845431745 and parameters: {'n_estimators': 118, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:47,842] Trial 25 finished with value: 0.23234637400284008 and parameters: {'n_estimators': 86, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:48,247] Trial 26 finished with value: 0.3796990025024094 and parameters: {'n_estimators': 125, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:48,621] Trial 27 finished with value: 0.37271641714244563 and parameters: {'n_estimators': 126, 'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:48,867] Trial 28 finished with value: 0.38806837503662783 and parameters: {'n_estimators': 88, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:49,125] Trial 29 finished with value: 0.37358828785263465 and parameters: {'n_estimators': 95, 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:49,201] Trial 30 finished with value: 0.23389619719493826 and parameters: {'n_estimators': 77, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:49,570] Trial 31 finished with value: 0.36756928194293137 and parameters: {'n_estimators': 128, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:49,741] Trial 32 finished with value: 0.3708494973115145 and parameters: {'n_estimators': 50, 'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:50,043] Trial 33 finished with value: 0.38917684726201607 and parameters: {'n_estimators': 98, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:50,351] Trial 34 finished with value: 0.38699483613358243 and parameters: {'n_estimators': 101, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:50,572] Trial 35 finished with value: 0.3851059242453585 and parameters: {'n_estimators': 68, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:50,669] Trial 36 finished with value: 0.23877002583751927 and parameters: {'n_estimators': 105, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:50,914] Trial 37 finished with value: 0.38419678921802236 and parameters: {'n_estimators': 77, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:51,037] Trial 38 finished with value: 0.21056695137827852 and parameters: {'n_estimators': 171, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:51,392] Trial 39 finished with value: 0.3698609900775156 and parameters: {'n_estimators': 99, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:51,530] Trial 40 finished with value: 0.260074017158912 and parameters: {'n_estimators': 116, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:51,771] Trial 41 finished with value: 0.3760233061741186 and parameters: {'n_estimators': 72, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:51,977] Trial 42 finished with value: 0.37686216636612124 and parameters: {'n_estimators': 64, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:52,045] Trial 43 finished with value: 0.16966640914873343 and parameters: {'n_estimators': 80, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:52,201] Trial 44 finished with value: 0.3722069280516971 and parameters: {'n_estimators': 50, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:52,417] Trial 45 finished with value: 0.3790113233496192 and parameters: {'n_estimators': 70, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:52,763] Trial 46 finished with value: 0.3771397749504981 and parameters: {'n_estimators': 99, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:52,944] Trial 47 finished with value: 0.20405005480498628 and parameters: {'n_estimators': 266, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:53,456] Trial 48 finished with value: 0.37655755492577747 and parameters: {'n_estimators': 201, 'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.
# [I 2025-06-02 19:01:53,840] Trial 49 finished with value: 0.3872888430484126 and parameters: {'n_estimators': 136, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 21 with value: 0.39307666658643026.

# %%
results_tuned
# Out:
#                            Model      R2     RMSE      MAE  Tuned
# 0                            XGB  0.1965  92.9168  59.4386   True
# 1                    XGB_Tweedie  0.2716  88.4664  55.0039   True
# 2                   RandomForest  0.2071  92.3055  59.0738   True
# 3               GradientBoosting  0.2428  90.2010  59.2880   True
# 4                       CatBoost  0.2889  87.4114  57.2577   True
# 5               CatBoost_Tweedie  0.3179  85.6113  53.3481   True
# 6  HistGradientBoostingRegressor  0.1739  94.2133  62.8600   True
# 7            ExtraTreesRegressor  0.2758  88.2144  59.4802   True

# %%
plot_metrics_comparison(results_tuned)

# %%
combined_results = pd.concat([results_untuned, results_tuned], ignore_index=True)
display(combined_results.sort_values(by=["R2"], ascending=False))
# Out:
#                             Model      R2      RMSE      MAE  Tuned
# 5                CatBoost_Tweedie  0.3215   85.3831  48.0945  False
# 13               CatBoost_Tweedie  0.3179   85.6113  53.3481   True
# 1                     XGB_Tweedie  0.3023   86.5880  48.1642  False
# 12                       CatBoost  0.2889   87.4114  57.2577   True
# 15            ExtraTreesRegressor  0.2758   88.2144  59.4802   True
# 9                     XGB_Tweedie  0.2716   88.4664  55.0039   True
# 11               GradientBoosting  0.2428   90.2010  59.2880   True
# 7             ExtraTreesRegressor  0.2115   92.0490  58.9141  False
# 4                        CatBoost  0.2102   92.1207  57.8841  False
# 10                   RandomForest  0.2071   92.3055  59.0738   True
# 8                             XGB  0.1965   92.9168  59.4386   True
# 3                GradientBoosting  0.1889   93.3546  61.9057  False
# 14  HistGradientBoostingRegressor  0.1739   94.2133  62.8600   True
# 2                    RandomForest  0.1687   94.5122  58.7291  False
# 0                             XGB  0.1210   97.1841  58.8789  False
# 6   HistGradientBoostingRegressor  0.0070  103.2943  64.3260  False

# %%
def plot_all_metrics(combined_results):
    melted = combined_results.melt(
        id_vars=["Model", "Tuned"],
        value_vars=["R2", "RMSE", "MAE"],
        var_name="Metric",
        value_name="Score"
    )

    plt.figure(figsize=(15, 5))
    sns.set(style="whitegrid")

    g = sns.catplot(
        data=melted,
        x="Score",
        y="Model",
        hue="Tuned",
        col="Metric",
        kind="bar",
        palette="Set2",
        sharex=False,
        height=5,
        aspect=1.2
    )

    g.fig.subplots_adjust(top=0.85)
    g.fig.suptitle("Сравнение моделей по метрикам (до и после тюнинга)")
    plt.show()
plot_all_metrics(combined_results)

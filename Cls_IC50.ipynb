# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier, ExtraTreesClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import optuna

# %%
# Устанавливаем глобальное начальное состояние генератора случайных чисел
np.random.seed(42)

# %%
df = pd.read_csv('data/df_ic50_iqr.csv')

# %%
# Найдем медиану по столбцу и добавим бинарное значение в датафрейм
median_ic50 = df['IC50'].median()
df['IC50_binary'] = (df['IC50'] > median_ic50).astype(int)

# %%
# Проверим баланс классов
df['IC50_binary'].value_counts()
# Out:
# IC50_binary
# 0    427
# 1    427
# Name: count, dtype: int64

# %% [markdown]
# Анализ целевой переменной показал, что классы идеально сбалансированы. Применение методов коррекции не требуется.

# %%
# Разделяем данные
X = df.drop(columns=['IC50', 'IC50_binary'])  # Убираем целевую переменную
y = df['IC50_binary']

# %%
# Делим исходные данные на тренировочную и тестовую выборки
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Теперь необходимо выбрать оптимальную модель.
#
# Для построения предсказательной модели были рассмотрены следующие алгоритмы:
#
# * XGBClassifier;
#
# * RandomForestClassifier;
#
# * GradientBoostingClassifier;
#
# * CatBoostClassifier;
#
# * HistGradientBoostingClassifier;
#
# * ExtraTreesClassifier.

# %%
models = {
    'XGB': XGBClassifier(eval_metric='logloss'),
    'RandomForest': RandomForestClassifier(),
    'GradientBoosting': GradientBoostingClassifier(),
    'CatBoost': CatBoostClassifier(verbose=0),
    'HistGradientBoosting': HistGradientBoostingClassifier(),
    'ExtraTrees': ExtraTreesClassifier()
}

# %%
def evaluate_models(models, X_train_full, y_train_full, X_test, y_test):
    results = []

    for name, model in models.items():
        pipeline = Pipeline([
            ('classifier', model)
        ])

        pipeline.fit(X_train_full, y_train_full)
        y_pred = pipeline.predict(X_test)

        y_pred_proba = pipeline.predict_proba(X_test)[:, 1]
        roc_auc = roc_auc_score(y_test, y_pred_proba)
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        results.append({
            'Model': name,
            'Accuracy': round(accuracy, 4),
            'ROC_AUC': round(roc_auc, 4) if roc_auc is not None else None,
            'F1': round(f1, 4),
            'Tuned': False
        })

    return pd.DataFrame(results)
results_untuned = evaluate_models(models, X_train_full, y_train_full, X_test, y_test)
display(results_untuned)
# Out:
#                   Model  Accuracy  ROC_AUC      F1  Tuned
# 0                   XGB    0.8012   0.8671  0.7875  False
# 1          RandomForest    0.7485   0.8500  0.7226  False
# 2      GradientBoosting    0.7895   0.8618  0.7778  False
# 3              CatBoost    0.7836   0.8654  0.7730  False
# 4  HistGradientBoosting    0.7953   0.8663  0.7799  False
# 5            ExtraTrees    0.7193   0.8229  0.6842  False

# %%
def plot_metrics_comparison(results_df):
    metrics = ['Accuracy', 'ROC_AUC', 'F1']
    fig, axs = plt.subplots(1, 3, figsize=(18, 5))

    for i, metric in enumerate(metrics):
        sns.barplot(data=results_df, x='Model', y=metric, ax=axs[i])
        axs[i].set_title(f'Сравнение моделей по {metric}')
        axs[i].set_xticks(range(len(results_df['Model'])))
        axs[i].set_xticklabels(results_df['Model'], rotation=45, ha='right')

    plt.tight_layout()
    plt.show()

plot_metrics_comparison(results_untuned)

# %%
def optuna_tuning(models, n_trials=50):
    results = []
    trained_models = {}

    # Проходим по всем моделям из переданного словаря
    for model_key, model in models.items():
        # Разбиваем данные на train/validation
        X_train, X_valid, y_train, y_valid = train_test_split(
            X_train_full, y_train_full, test_size=0.2, random_state=42
        )

        # Определяем функцию-цель для Optuna
        def objective(trial):
            # Для каждой модели формируем свой словарь параметров
            if model_key == 'XGB':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 500),
                    'max_depth': trial.suggest_int('max_depth', 3, 10),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'subsample': trial.suggest_float('subsample', 0.5, 1.0),
                    'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
                    'gamma': trial.suggest_float('gamma', 0, 5),
                    'min_child_weight': trial.suggest_int('min_child_weight', 1, 10)
                }
                reg = XGBClassifier(**params)

            elif model_key == 'RandomForest':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 300),
                    'max_depth': trial.suggest_int('max_depth', 3, 20),
                    'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
                    'max_features': trial.suggest_categorical('max_features', ['log2', 'sqrt', None])
                }
                reg = RandomForestClassifier(**params)

            elif model_key == 'GradientBoosting':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 300),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'max_depth': trial.suggest_int('max_depth', 3, 10),
                    'subsample': trial.suggest_float('subsample', 0.5, 1.0),
                    'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
                    'max_features': trial.suggest_categorical('max_features', [None, 'sqrt', 'log2'])
                }
                reg = GradientBoostingClassifier(**params, random_state=42)

            elif model_key == 'CatBoost':
                params = {
                    'iterations': trial.suggest_int('iterations', 100, 1000),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'depth': trial.suggest_int('depth', 4, 10),
                    'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 10),
                    'bagging_temperature': trial.suggest_float('bagging_temperature', 0, 1)
                }
                reg = CatBoostClassifier(**params, verbose=False)

            elif model_key == 'HistGradientBoosting':
                params = {
                    'max_iter': trial.suggest_int('max_iter', 50, 300),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'max_depth': trial.suggest_int('max_depth', 3, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 20),
                    'l2_regularization': trial.suggest_float('l2_regularization', 0, 1)
                }
                reg = HistGradientBoostingClassifier(**params)

            elif model_key == 'ExtraTrees':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 300),
                    'max_depth': trial.suggest_int('max_depth', 3, 20),
                    'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
                    'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
                }
                reg = ExtraTreesClassifier(**params)

            # Обучаем на train и проверяем accuracy_score на valid
            reg.fit(X_train, y_train)
            y_pred = reg.predict(X_valid)
            return accuracy_score(y_valid, y_pred)

        # Запускаем оптимизацию Optuna
        study = optuna.create_study(direction='maximize')
        study.optimize(objective, n_trials=n_trials)

        # Формируем финальную модель с лучшими гиперпараметрами
        best_params = study.best_params

        if model_key == 'XGB':
            final_model = XGBClassifier(**best_params)

        elif model_key == 'RandomForest':
            final_model = RandomForestClassifier(**best_params)

        elif model_key == 'GradientBoosting':
            final_model = GradientBoostingClassifier(**best_params)

        elif model_key == 'CatBoost':
            final_model = CatBoostClassifier(**best_params, verbose=False)

        elif model_key == 'HistGradientBoosting':
            final_model = HistGradientBoostingClassifier(**best_params)

        elif model_key == 'ExtraTrees':
            final_model = ExtraTreesClassifier(**best_params)

        # Обучаем финальную модель на полном тренировочном наборе
        final_model.fit(X_train_full, y_train_full)

        # Сохраняем обученную модель в словарь trained_models
        trained_models[model_key] = final_model

        # Оцениваем финальную модель на тестовом наборе
        y_test_pred = final_model.predict(X_test)
        y_test_proba = final_model.predict_proba(X_test)[:, 1]
        
        test_f1 = f1_score(y_test, y_test_pred)
        test_accuracy = accuracy_score(y_test, y_test_pred)
        test_roc_auc = roc_auc_score(y_test, y_test_proba)

        # Сохраняем метрики в список results
        results.append({
            'Model': model_key,
            'F1': round(test_f1, 4),
            'Accuracy': round(test_accuracy, 4),
            'ROC_AUC': round(test_roc_auc, 4),
            'Tuned': True
        })

    # Превращаем список результатов в DataFrame
    results_tuned = pd.DataFrame(results)

    # Возвращаем две структуры: DataFrame и словарь обученных моделей
    return results_tuned, trained_models

# %%
results_tuned, trained_models = optuna_tuning(models)
# Out:
# [I 2025-06-02 20:02:25,875] A new study created in memory with name: no-name-1573df4d-2242-47da-9e0c-7a7cca14a603
# [I 2025-06-02 20:02:26,601] Trial 0 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 359, 'max_depth': 5, 'learning_rate': 0.026266441657989505, 'subsample': 0.842799097176038, 'colsample_bytree': 0.9293522629843478, 'gamma': 0.4451245071398041, 'min_child_weight': 9}. Best is trial 0 with value: 0.7372262773722628.
# [I 2025-06-02 20:02:26,795] Trial 1 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 203, 'max_depth': 9, 'learning_rate': 0.14717692426672307, 'subsample': 0.9255349062712481, 'colsample_bytree': 0.7219604297820661, 'gamma': 2.2454068230848563, 'min_child_weight': 9}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:27,311] Trial 2 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 96, 'max_depth': 9, 'learning_rate': 0.02992580192690801, 'subsample': 0.7591675011762845, 'colsample_bytree': 0.9368195704781783, 'gamma': 0.9886005079932114, 'min_child_weight': 1}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:27,418] Trial 3 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 102, 'max_depth': 8, 'learning_rate': 0.22311225960540293, 'subsample': 0.9655967886156595, 'colsample_bytree': 0.5682518340059557, 'gamma': 4.046278978547885, 'min_child_weight': 9}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:27,612] Trial 4 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 164, 'max_depth': 6, 'learning_rate': 0.14853291101622387, 'subsample': 0.7496993819845852, 'colsample_bytree': 0.830161188502853, 'gamma': 2.755898323681464, 'min_child_weight': 6}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:27,829] Trial 5 finished with value: 0.708029197080292 and parameters: {'n_estimators': 103, 'max_depth': 6, 'learning_rate': 0.15088215712421005, 'subsample': 0.6999362290214421, 'colsample_bytree': 0.5948166495294847, 'gamma': 2.3131191433090375, 'min_child_weight': 9}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:28,036] Trial 6 finished with value: 0.708029197080292 and parameters: {'n_estimators': 287, 'max_depth': 3, 'learning_rate': 0.21985298936214348, 'subsample': 0.7412134006593536, 'colsample_bytree': 0.9961797781940489, 'gamma': 4.96045861784839, 'min_child_weight': 4}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:28,200] Trial 7 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 156, 'max_depth': 6, 'learning_rate': 0.16969584869000245, 'subsample': 0.778941381441953, 'colsample_bytree': 0.8645930146561523, 'gamma': 2.079595839110741, 'min_child_weight': 3}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:28,447] Trial 8 finished with value: 0.7007299270072993 and parameters: {'n_estimators': 247, 'max_depth': 5, 'learning_rate': 0.28759679331614046, 'subsample': 0.8473379255635953, 'colsample_bytree': 0.6610627296943148, 'gamma': 4.039636440264022, 'min_child_weight': 10}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:28,640] Trial 9 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 335, 'max_depth': 9, 'learning_rate': 0.2896630740834848, 'subsample': 0.9083876622756284, 'colsample_bytree': 0.5493179933279895, 'gamma': 2.486390285091453, 'min_child_weight': 4}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:29,122] Trial 10 finished with value: 0.708029197080292 and parameters: {'n_estimators': 474, 'max_depth': 10, 'learning_rate': 0.08668172022013197, 'subsample': 0.5494122731989515, 'colsample_bytree': 0.7135835185009084, 'gamma': 1.207121659686766, 'min_child_weight': 7}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:29,382] Trial 11 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 50, 'max_depth': 8, 'learning_rate': 0.012121743106109084, 'subsample': 0.6016144774985923, 'colsample_bytree': 0.7877050868738052, 'gamma': 1.2388523241033362, 'min_child_weight': 1}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:30,041] Trial 12 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 201, 'max_depth': 10, 'learning_rate': 0.06897807507452598, 'subsample': 0.9849959267700212, 'colsample_bytree': 0.7317104728486719, 'gamma': 0.02529485816107524, 'min_child_weight': 1}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:02:30,282] Trial 13 finished with value: 0.7664233576642335 and parameters: {'n_estimators': 226, 'max_depth': 8, 'learning_rate': 0.10052836199441031, 'subsample': 0.8768874973921915, 'colsample_bytree': 0.8861449935911447, 'gamma': 1.3102560096984162, 'min_child_weight': 7}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:30,506] Trial 14 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 240, 'max_depth': 8, 'learning_rate': 0.09818666837372612, 'subsample': 0.8979033259130296, 'colsample_bytree': 0.661512481021607, 'gamma': 1.8004553774830436, 'min_child_weight': 7}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:30,836] Trial 15 finished with value: 0.7226277372262774 and parameters: {'n_estimators': 406, 'max_depth': 7, 'learning_rate': 0.11700084629962684, 'subsample': 0.9142843765349251, 'colsample_bytree': 0.8597412152601827, 'gamma': 3.2512641470195827, 'min_child_weight': 7}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:31,074] Trial 16 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 298, 'max_depth': 9, 'learning_rate': 0.19388173230909272, 'subsample': 0.8361469937895962, 'colsample_bytree': 0.7771717001731543, 'gamma': 1.6723001631177934, 'min_child_weight': 8}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:31,237] Trial 17 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 185, 'max_depth': 7, 'learning_rate': 0.12514846335025465, 'subsample': 0.670240424277292, 'colsample_bytree': 0.6638504500008288, 'gamma': 3.081930039138516, 'min_child_weight': 5}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:31,504] Trial 18 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 225, 'max_depth': 10, 'learning_rate': 0.05862403794535945, 'subsample': 0.993056298981764, 'colsample_bytree': 0.913899289302502, 'gamma': 0.6608126880470491, 'min_child_weight': 10}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:31,734] Trial 19 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 332, 'max_depth': 8, 'learning_rate': 0.18905058074212555, 'subsample': 0.9360019048762016, 'colsample_bytree': 0.9960621816810813, 'gamma': 1.5760134006334294, 'min_child_weight': 8}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:32,024] Trial 20 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 413, 'max_depth': 4, 'learning_rate': 0.25160157167675457, 'subsample': 0.8153514726927762, 'colsample_bytree': 0.9955878935766352, 'gamma': 1.440280100706577, 'min_child_weight': 6}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:32,483] Trial 21 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 333, 'max_depth': 8, 'learning_rate': 0.17878257922035268, 'subsample': 0.9334297199409912, 'colsample_bytree': 0.9550281769917174, 'gamma': 2.1056913663702477, 'min_child_weight': 8}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:32,945] Trial 22 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 260, 'max_depth': 9, 'learning_rate': 0.12764380911093992, 'subsample': 0.8747550060383932, 'colsample_bytree': 0.5023537281132069, 'gamma': 0.7272796887451642, 'min_child_weight': 8}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:33,276] Trial 23 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 377, 'max_depth': 7, 'learning_rate': 0.18937001981849086, 'subsample': 0.9318032887311758, 'colsample_bytree': 0.8922076187096346, 'gamma': 1.7340310652242152, 'min_child_weight': 8}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:33,534] Trial 24 finished with value: 0.7664233576642335 and parameters: {'n_estimators': 301, 'max_depth': 8, 'learning_rate': 0.22239447892325193, 'subsample': 0.9478944212940762, 'colsample_bytree': 0.8210467323512991, 'gamma': 2.8363615869734833, 'min_child_weight': 10}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:33,783] Trial 25 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 323, 'max_depth': 8, 'learning_rate': 0.22010384120953844, 'subsample': 0.9610333547815872, 'colsample_bytree': 0.8549612924311376, 'gamma': 3.5967018169541736, 'min_child_weight': 10}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:34,094] Trial 26 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 466, 'max_depth': 7, 'learning_rate': 0.25458383901647813, 'subsample': 0.8767873534094852, 'colsample_bytree': 0.8138973865835308, 'gamma': 2.8444184326364486, 'min_child_weight': 7}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:34,428] Trial 27 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 293, 'max_depth': 8, 'learning_rate': 0.25823465406343393, 'subsample': 0.7979520483512443, 'colsample_bytree': 0.9629357213541879, 'gamma': 0.07084937647390044, 'min_child_weight': 6}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:34,674] Trial 28 finished with value: 0.708029197080292 and parameters: {'n_estimators': 422, 'max_depth': 7, 'learning_rate': 0.2060081331266972, 'subsample': 0.9998786103438213, 'colsample_bytree': 0.8926550821134259, 'gamma': 3.493538752475779, 'min_child_weight': 10}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:34,995] Trial 29 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 357, 'max_depth': 5, 'learning_rate': 0.2418569728574519, 'subsample': 0.8707814482123153, 'colsample_bytree': 0.9008567135151454, 'gamma': 0.9740987116255078, 'min_child_weight': 9}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:35,337] Trial 30 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 376, 'max_depth': 9, 'learning_rate': 0.1628141553854989, 'subsample': 0.9419557211772582, 'colsample_bytree': 0.7690077067351261, 'gamma': 2.6271042211969187, 'min_child_weight': 9}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:35,667] Trial 31 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 195, 'max_depth': 9, 'learning_rate': 0.13999905369489818, 'subsample': 0.9595732404656362, 'colsample_bytree': 0.7084672225285817, 'gamma': 2.1486335839944894, 'min_child_weight': 8}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:35,880] Trial 32 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 223, 'max_depth': 8, 'learning_rate': 0.10849718148630738, 'subsample': 0.8478030769254923, 'colsample_bytree': 0.8112891041625916, 'gamma': 1.8898371964523946, 'min_child_weight': 9}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:36,259] Trial 33 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 266, 'max_depth': 10, 'learning_rate': 0.06038523699852184, 'subsample': 0.9021831295322013, 'colsample_bytree': 0.9433591414527328, 'gamma': 1.4340010941147288, 'min_child_weight': 9}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:36,393] Trial 34 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 145, 'max_depth': 9, 'learning_rate': 0.2040943548064958, 'subsample': 0.9556960566013315, 'colsample_bytree': 0.7449362301103112, 'gamma': 2.879637081964005, 'min_child_weight': 10}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:36,522] Trial 35 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 128, 'max_depth': 8, 'learning_rate': 0.14295733831805413, 'subsample': 0.9240532155242728, 'colsample_bytree': 0.6927209112215815, 'gamma': 2.374845195176898, 'min_child_weight': 9}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:36,807] Trial 36 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 306, 'max_depth': 9, 'learning_rate': 0.08333684963181512, 'subsample': 0.8833908048578438, 'colsample_bytree': 0.8296546396006508, 'gamma': 0.9359013880751372, 'min_child_weight': 7}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:36,995] Trial 37 finished with value: 0.7226277372262774 and parameters: {'n_estimators': 178, 'max_depth': 6, 'learning_rate': 0.17076542209610368, 'subsample': 0.9757967967386096, 'colsample_bytree': 0.9807533820322066, 'gamma': 0.4591515348040889, 'min_child_weight': 8}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:37,199] Trial 38 finished with value: 0.7226277372262774 and parameters: {'n_estimators': 227, 'max_depth': 8, 'learning_rate': 0.23382680266029235, 'subsample': 0.7058610978562416, 'colsample_bytree': 0.9312801611838226, 'gamma': 1.5153025055093758, 'min_child_weight': 5}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:37,631] Trial 39 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 351, 'max_depth': 7, 'learning_rate': 0.1535745001773422, 'subsample': 0.809533477847392, 'colsample_bytree': 0.8732926662821647, 'gamma': 1.9420258933422208, 'min_child_weight': 10}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:37,904] Trial 40 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 284, 'max_depth': 6, 'learning_rate': 0.045879181920307835, 'subsample': 0.8434234968039923, 'colsample_bytree': 0.7967124302447119, 'gamma': 2.3174065769681653, 'min_child_weight': 8}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:38,178] Trial 41 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 95, 'max_depth': 9, 'learning_rate': 0.024978059851444676, 'subsample': 0.7517778434743199, 'colsample_bytree': 0.92717936775754, 'gamma': 1.136213557924392, 'min_child_weight': 2}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:38,400] Trial 42 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 76, 'max_depth': 9, 'learning_rate': 0.03994494155849088, 'subsample': 0.7673706056254375, 'colsample_bytree': 0.921885683281818, 'gamma': 1.2756188991320776, 'min_child_weight': 2}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:38,594] Trial 43 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 71, 'max_depth': 9, 'learning_rate': 0.04329092620367245, 'subsample': 0.720369681408028, 'colsample_bytree': 0.918450338398345, 'gamma': 1.1948790384055028, 'min_child_weight': 2}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:38,891] Trial 44 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 113, 'max_depth': 10, 'learning_rate': 0.010672993564136951, 'subsample': 0.6476541432536062, 'colsample_bytree': 0.9672968780693596, 'gamma': 0.6764726004937645, 'min_child_weight': 2}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:39,276] Trial 45 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 76, 'max_depth': 8, 'learning_rate': 0.03358485974675043, 'subsample': 0.7524669727392729, 'colsample_bytree': 0.9349895522582948, 'gamma': 0.3772628760797685, 'min_child_weight': 3}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:39,473] Trial 46 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 79, 'max_depth': 9, 'learning_rate': 0.27508483429545094, 'subsample': 0.7798230499726251, 'colsample_bytree': 0.8446939828012219, 'gamma': 1.1523693836057847, 'min_child_weight': 2}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:39,990] Trial 47 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 139, 'max_depth': 10, 'learning_rate': 0.024694875503809013, 'subsample': 0.7310464152064696, 'colsample_bytree': 0.8753852496179235, 'gamma': 1.4472052680964802, 'min_child_weight': 3}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:40,191] Trial 48 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 111, 'max_depth': 8, 'learning_rate': 0.07252872390487793, 'subsample': 0.6682299745409112, 'colsample_bytree': 0.9998442482399005, 'gamma': 4.570484652249739, 'min_child_weight': 4}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:40,966] Trial 49 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 313, 'max_depth': 9, 'learning_rate': 0.021771281500042084, 'subsample': 0.7754472805792526, 'colsample_bytree': 0.916165125525969, 'gamma': 0.9371590701931047, 'min_child_weight': 1}. Best is trial 13 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:41,256] A new study created in memory with name: no-name-f777dae2-d8d1-40ff-b540-8c0b60cdd250
# [I 2025-06-02 20:02:41,403] Trial 0 finished with value: 0.708029197080292 and parameters: {'n_estimators': 99, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.708029197080292.
# [I 2025-06-02 20:02:41,724] Trial 1 finished with value: 0.6642335766423357 and parameters: {'n_estimators': 278, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 0 with value: 0.708029197080292.
# [I 2025-06-02 20:02:41,977] Trial 2 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 144, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 2 with value: 0.7372262773722628.
# [I 2025-06-02 20:02:44,156] Trial 3 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 210, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 3 with value: 0.7591240875912408.
# [I 2025-06-02 20:02:44,324] Trial 4 finished with value: 0.7007299270072993 and parameters: {'n_estimators': 116, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 3 with value: 0.7591240875912408.
# [I 2025-06-02 20:02:44,627] Trial 5 finished with value: 0.6934306569343066 and parameters: {'n_estimators': 227, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.7591240875912408.
# [I 2025-06-02 20:02:45,340] Trial 6 finished with value: 0.7664233576642335 and parameters: {'n_estimators': 77, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 6 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:45,615] Trial 7 finished with value: 0.708029197080292 and parameters: {'n_estimators': 159, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:46,205] Trial 8 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 65, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 6 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:46,658] Trial 9 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 284, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 6 with value: 0.7664233576642335.
# [I 2025-06-02 20:02:47,148] Trial 10 finished with value: 0.7737226277372263 and parameters: {'n_estimators': 54, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 10 with value: 0.7737226277372263.
# [I 2025-06-02 20:02:47,660] Trial 11 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 55, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 10 with value: 0.7737226277372263.
# [I 2025-06-02 20:02:48,689] Trial 12 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 99, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 10 with value: 0.7737226277372263.
# [I 2025-06-02 20:02:49,240] Trial 13 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 60, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 10 with value: 0.7737226277372263.
# [I 2025-06-02 20:02:50,480] Trial 14 finished with value: 0.781021897810219 and parameters: {'n_estimators': 128, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:02:51,933] Trial 15 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 131, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:02:53,804] Trial 16 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 191, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:02:56,081] Trial 17 finished with value: 0.7664233576642335 and parameters: {'n_estimators': 246, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:02:57,234] Trial 18 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 174, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:02:57,408] Trial 19 finished with value: 0.708029197080292 and parameters: {'n_estimators': 98, 'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:02:58,754] Trial 20 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 128, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:02:59,505] Trial 21 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 81, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:00,287] Trial 22 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 81, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:00,784] Trial 23 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 51, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:01,600] Trial 24 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 78, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:02,611] Trial 25 finished with value: 0.7737226277372263 and parameters: {'n_estimators': 104, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:04,423] Trial 26 finished with value: 0.7664233576642335 and parameters: {'n_estimators': 153, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:05,713] Trial 27 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 112, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:05,979] Trial 28 finished with value: 0.7226277372262774 and parameters: {'n_estimators': 125, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:06,139] Trial 29 finished with value: 0.708029197080292 and parameters: {'n_estimators': 104, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:06,463] Trial 30 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 174, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:07,159] Trial 31 finished with value: 0.7664233576642335 and parameters: {'n_estimators': 84, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:07,930] Trial 32 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 69, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:08,599] Trial 33 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 91, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:09,893] Trial 34 finished with value: 0.7737226277372263 and parameters: {'n_estimators': 140, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:10,071] Trial 35 finished with value: 0.6861313868613139 and parameters: {'n_estimators': 146, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:11,485] Trial 36 finished with value: 0.781021897810219 and parameters: {'n_estimators': 135, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:11,677] Trial 37 finished with value: 0.708029197080292 and parameters: {'n_estimators': 117, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:13,499] Trial 38 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 164, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:15,841] Trial 39 finished with value: 0.7664233576642335 and parameters: {'n_estimators': 194, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:16,119] Trial 40 finished with value: 0.6861313868613139 and parameters: {'n_estimators': 140, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:18,308] Trial 41 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 300, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:19,647] Trial 42 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 136, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:20,683] Trial 43 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 113, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:22,156] Trial 44 finished with value: 0.7737226277372263 and parameters: {'n_estimators': 149, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:23,740] Trial 45 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 160, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:23,900] Trial 46 finished with value: 0.7007299270072993 and parameters: {'n_estimators': 105, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:25,070] Trial 47 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 123, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:27,045] Trial 48 finished with value: 0.7737226277372263 and parameters: {'n_estimators': 187, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:28,588] Trial 49 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 206, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 14 with value: 0.781021897810219.
# [I 2025-06-02 20:03:30,178] A new study created in memory with name: no-name-29bab7e1-d1fe-4b56-9c6c-6f9d4e2bef71
# [I 2025-06-02 20:03:30,980] Trial 0 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 60, 'learning_rate': 0.2663179378111469, 'max_depth': 8, 'subsample': 0.77231456739808, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 0 with value: 0.7153284671532847.
# [I 2025-06-02 20:03:31,259] Trial 1 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 300, 'learning_rate': 0.07710124632154462, 'max_depth': 3, 'subsample': 0.6838427947084114, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 0 with value: 0.7153284671532847.
# [I 2025-06-02 20:03:31,763] Trial 2 finished with value: 0.6715328467153284 and parameters: {'n_estimators': 275, 'learning_rate': 0.28131363134423787, 'max_depth': 10, 'subsample': 0.5191844761915324, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 0 with value: 0.7153284671532847.
# [I 2025-06-02 20:03:34,388] Trial 3 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 269, 'learning_rate': 0.18382342221503795, 'max_depth': 4, 'subsample': 0.9699254526745259, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 3 with value: 0.7299270072992701.
# [I 2025-06-02 20:03:34,813] Trial 4 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 229, 'learning_rate': 0.2868450182936336, 'max_depth': 5, 'subsample': 0.9532488003300121, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.7299270072992701.
# [I 2025-06-02 20:03:35,213] Trial 5 finished with value: 0.6934306569343066 and parameters: {'n_estimators': 230, 'learning_rate': 0.13668354510467004, 'max_depth': 6, 'subsample': 0.6464081329281242, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.7299270072992701.
# [I 2025-06-02 20:03:35,754] Trial 6 finished with value: 0.7737226277372263 and parameters: {'n_estimators': 205, 'learning_rate': 0.08633063658632845, 'max_depth': 7, 'subsample': 0.9325688368730829, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:37,271] Trial 7 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 197, 'learning_rate': 0.12735699263956748, 'max_depth': 6, 'subsample': 0.5366454995887424, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:37,542] Trial 8 finished with value: 0.7226277372262774 and parameters: {'n_estimators': 165, 'learning_rate': 0.1315098557395872, 'max_depth': 6, 'subsample': 0.7586846160291842, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:37,835] Trial 9 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 232, 'learning_rate': 0.13213577684698952, 'max_depth': 3, 'subsample': 0.8448992140798561, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:38,445] Trial 10 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 137, 'learning_rate': 0.027980508499726775, 'max_depth': 8, 'subsample': 0.8792935661142389, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:39,581] Trial 11 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 114, 'learning_rate': 0.21127266558597713, 'max_depth': 4, 'subsample': 0.9788321857710559, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:44,155] Trial 12 finished with value: 0.6934306569343066 and parameters: {'n_estimators': 265, 'learning_rate': 0.19913404928175807, 'max_depth': 8, 'subsample': 0.8952349118156266, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:44,692] Trial 13 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 201, 'learning_rate': 0.06659551190612421, 'max_depth': 7, 'subsample': 0.9940400221631553, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:45,272] Trial 14 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 182, 'learning_rate': 0.06567651431530101, 'max_depth': 10, 'subsample': 0.8335473187690303, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:45,692] Trial 15 finished with value: 0.7007299270072993 and parameters: {'n_estimators': 149, 'learning_rate': 0.08299585640358745, 'max_depth': 7, 'subsample': 0.9961515427919754, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:46,367] Trial 16 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 199, 'learning_rate': 0.015339034431394512, 'max_depth': 9, 'subsample': 0.918934522126218, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:46,718] Trial 17 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 100, 'learning_rate': 0.01086801646462289, 'max_depth': 9, 'subsample': 0.9185657418290271, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:47,360] Trial 18 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 210, 'learning_rate': 0.04140221184068159, 'max_depth': 9, 'subsample': 0.813944654982558, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:47,727] Trial 19 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 165, 'learning_rate': 0.0989603913894619, 'max_depth': 9, 'subsample': 0.6622448393949711, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:48,199] Trial 20 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 252, 'learning_rate': 0.04664012924438009, 'max_depth': 7, 'subsample': 0.9113621618784069, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:48,680] Trial 21 finished with value: 0.7664233576642335 and parameters: {'n_estimators': 249, 'learning_rate': 0.043595820533960786, 'max_depth': 7, 'subsample': 0.9213874002938354, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:49,138] Trial 22 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 218, 'learning_rate': 0.011220481268873983, 'max_depth': 8, 'subsample': 0.92213560091539, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:49,538] Trial 23 finished with value: 0.6934306569343066 and parameters: {'n_estimators': 247, 'learning_rate': 0.10276193663929614, 'max_depth': 5, 'subsample': 0.8615101262397785, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:49,916] Trial 24 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 183, 'learning_rate': 0.043098221948759056, 'max_depth': 7, 'subsample': 0.7971524852843408, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:50,765] Trial 25 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 292, 'learning_rate': 0.09649930568222934, 'max_depth': 9, 'subsample': 0.9395639771892906, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:51,159] Trial 26 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 248, 'learning_rate': 0.05838415749935033, 'max_depth': 5, 'subsample': 0.8800814793408286, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:51,757] Trial 27 finished with value: 0.7664233576642335 and parameters: {'n_estimators': 197, 'learning_rate': 0.027098495416183532, 'max_depth': 10, 'subsample': 0.9474794093843744, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:52,198] Trial 28 finished with value: 0.7226277372262774 and parameters: {'n_estimators': 141, 'learning_rate': 0.1650856508420956, 'max_depth': 10, 'subsample': 0.9593619951923203, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:52,352] Trial 29 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 63, 'learning_rate': 0.2411765075421832, 'max_depth': 8, 'subsample': 0.7328768937927596, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:54,150] Trial 30 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 184, 'learning_rate': 0.0325752138575476, 'max_depth': 6, 'subsample': 0.7156436227130321, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:54,752] Trial 31 finished with value: 0.7591240875912408 and parameters: {'n_estimators': 202, 'learning_rate': 0.022743254210255286, 'max_depth': 10, 'subsample': 0.9374508857868945, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:55,327] Trial 32 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 221, 'learning_rate': 0.05276803637080725, 'max_depth': 9, 'subsample': 0.8912991032432004, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:55,752] Trial 33 finished with value: 0.7226277372262774 and parameters: {'n_estimators': 164, 'learning_rate': 0.07794054268116876, 'max_depth': 10, 'subsample': 0.5838521675362878, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:56,294] Trial 34 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 194, 'learning_rate': 0.020445033315527217, 'max_depth': 9, 'subsample': 0.7886114593303499, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:56,916] Trial 35 finished with value: 0.708029197080292 and parameters: {'n_estimators': 241, 'learning_rate': 0.03657071238317637, 'max_depth': 8, 'subsample': 0.8558857994599246, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:57,658] Trial 36 finished with value: 0.7226277372262774 and parameters: {'n_estimators': 279, 'learning_rate': 0.11460874236866375, 'max_depth': 7, 'subsample': 0.9626245966975236, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:03:58,332] Trial 37 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 257, 'learning_rate': 0.0814747144434264, 'max_depth': 10, 'subsample': 0.8290179270720522, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:01,304] Trial 38 finished with value: 0.7226277372262774 and parameters: {'n_estimators': 214, 'learning_rate': 0.06354246323474545, 'max_depth': 8, 'subsample': 0.9340573891202553, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:01,737] Trial 39 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 233, 'learning_rate': 0.027815024847754617, 'max_depth': 6, 'subsample': 0.9720523648699034, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:02,539] Trial 40 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 281, 'learning_rate': 0.15652248222047832, 'max_depth': 9, 'subsample': 0.9035702566072384, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:02,878] Trial 41 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 177, 'learning_rate': 0.04620683197353388, 'max_depth': 7, 'subsample': 0.7799973039404213, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:03,210] Trial 42 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 155, 'learning_rate': 0.04289217357817643, 'max_depth': 7, 'subsample': 0.8649565694025322, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:03,483] Trial 43 finished with value: 0.6934306569343066 and parameters: {'n_estimators': 126, 'learning_rate': 0.019667541081537745, 'max_depth': 8, 'subsample': 0.8148676076970169, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:03,810] Trial 44 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 186, 'learning_rate': 0.07142597129774539, 'max_depth': 6, 'subsample': 0.5939125306496458, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:04,091] Trial 45 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 195, 'learning_rate': 0.05369674848308957, 'max_depth': 4, 'subsample': 0.9476827131191244, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:07,353] Trial 46 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 208, 'learning_rate': 0.09143040274729947, 'max_depth': 7, 'subsample': 0.9933878759378927, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:07,925] Trial 47 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 226, 'learning_rate': 0.03457757255389339, 'max_depth': 6, 'subsample': 0.8809602314639052, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:08,242] Trial 48 finished with value: 0.7007299270072993 and parameters: {'n_estimators': 174, 'learning_rate': 0.1121379892926879, 'max_depth': 5, 'subsample': 0.6965637299299794, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:08,703] Trial 49 finished with value: 0.7226277372262774 and parameters: {'n_estimators': 236, 'learning_rate': 0.2973886924710212, 'max_depth': 7, 'subsample': 0.751536235406965, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 6 with value: 0.7737226277372263.
# [I 2025-06-02 20:04:09,305] A new study created in memory with name: no-name-558c34ef-d134-406d-ab44-e354e2457453
# [I 2025-06-02 20:04:25,087] Trial 0 finished with value: 0.708029197080292 and parameters: {'iterations': 382, 'learning_rate': 0.17349468566471976, 'depth': 10, 'l2_leaf_reg': 8.570232818769828, 'bagging_temperature': 0.21300041792065239}. Best is trial 0 with value: 0.708029197080292.
# [I 2025-06-02 20:04:26,822] Trial 1 finished with value: 0.7153284671532847 and parameters: {'iterations': 428, 'learning_rate': 0.0733230184000298, 'depth': 6, 'l2_leaf_reg': 4.635686553233851, 'bagging_temperature': 0.1474640505658189}. Best is trial 1 with value: 0.7153284671532847.
# [I 2025-06-02 20:04:28,133] Trial 2 finished with value: 0.7226277372262774 and parameters: {'iterations': 198, 'learning_rate': 0.04084394716115823, 'depth': 7, 'l2_leaf_reg': 1.4284459036679975, 'bagging_temperature': 0.639053094796193}. Best is trial 2 with value: 0.7226277372262774.
# [I 2025-06-02 20:04:38,224] Trial 3 finished with value: 0.7226277372262774 and parameters: {'iterations': 818, 'learning_rate': 0.2972906734474656, 'depth': 8, 'l2_leaf_reg': 5.878484905462512, 'bagging_temperature': 0.7703991754307858}. Best is trial 2 with value: 0.7226277372262774.
# [I 2025-06-02 20:04:40,107] Trial 4 finished with value: 0.7299270072992701 and parameters: {'iterations': 800, 'learning_rate': 0.21805954804812216, 'depth': 4, 'l2_leaf_reg': 5.302054205774196, 'bagging_temperature': 0.42593588472657695}. Best is trial 4 with value: 0.7299270072992701.
# [I 2025-06-02 20:04:50,939] Trial 5 finished with value: 0.7153284671532847 and parameters: {'iterations': 841, 'learning_rate': 0.19641894485229439, 'depth': 8, 'l2_leaf_reg': 3.917190652266754, 'bagging_temperature': 0.8835162236290632}. Best is trial 4 with value: 0.7299270072992701.
# ...
# [I 2025-06-02 20:09:29,480] Trial 38 finished with value: 0.7591240875912408 and parameters: {'max_iter': 193, 'learning_rate': 0.2579642725016982, 'max_depth': 3, 'min_samples_leaf': 3, 'l2_regularization': 0.6573559472596298}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:29,726] Trial 39 finished with value: 0.7299270072992701 and parameters: {'max_iter': 198, 'learning_rate': 0.24683900397077976, 'max_depth': 3, 'min_samples_leaf': 1, 'l2_regularization': 0.8966309052893312}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:30,000] Trial 40 finished with value: 0.7299270072992701 and parameters: {'max_iter': 147, 'learning_rate': 0.047782231754946405, 'max_depth': 4, 'min_samples_leaf': 3, 'l2_regularization': 0.744063483908636}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:30,218] Trial 41 finished with value: 0.7372262773722628 and parameters: {'max_iter': 164, 'learning_rate': 0.26390180366881255, 'max_depth': 3, 'min_samples_leaf': 7, 'l2_regularization': 0.685417566501545}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:30,457] Trial 42 finished with value: 0.7445255474452555 and parameters: {'max_iter': 193, 'learning_rate': 0.29937968142854204, 'max_depth': 3, 'min_samples_leaf': 5, 'l2_regularization': 0.8973021740470348}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:30,690] Trial 43 finished with value: 0.7226277372262774 and parameters: {'max_iter': 112, 'learning_rate': 0.2826788589119481, 'max_depth': 4, 'min_samples_leaf': 3, 'l2_regularization': 0.9959751654099569}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:30,952] Trial 44 finished with value: 0.7153284671532847 and parameters: {'max_iter': 215, 'learning_rate': 0.2362397586243203, 'max_depth': 3, 'min_samples_leaf': 4, 'l2_regularization': 0.6384910168772088}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:31,225] Trial 45 finished with value: 0.7445255474452555 and parameters: {'max_iter': 234, 'learning_rate': 0.2667540892773782, 'max_depth': 3, 'min_samples_leaf': 9, 'l2_regularization': 0.8182231188340456}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:31,796] Trial 46 finished with value: 0.7153284671532847 and parameters: {'max_iter': 275, 'learning_rate': 0.28791326177841764, 'max_depth': 5, 'min_samples_leaf': 7, 'l2_regularization': 0.4446746617731999}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:32,193] Trial 47 finished with value: 0.7226277372262774 and parameters: {'max_iter': 263, 'learning_rate': 0.255243947962002, 'max_depth': 4, 'min_samples_leaf': 8, 'l2_regularization': 0.7574697140567804}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:32,515] Trial 48 finished with value: 0.7372262773722628 and parameters: {'max_iter': 296, 'learning_rate': 0.21512918038624534, 'max_depth': 3, 'min_samples_leaf': 2, 'l2_regularization': 0.3461311240582926}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:33,042] Trial 49 finished with value: 0.7445255474452555 and parameters: {'max_iter': 207, 'learning_rate': 0.14363293201641822, 'max_depth': 6, 'min_samples_leaf': 6, 'l2_regularization': 0.5083331564437765}. Best is trial 21 with value: 0.7664233576642335.
# [I 2025-06-02 20:09:33,293] A new study created in memory with name: no-name-b281e9b8-409a-4547-9039-eacfe2b99c55
# [I 2025-06-02 20:09:33,608] Trial 0 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 89, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 0 with value: 0.7299270072992701.
# [I 2025-06-02 20:09:34,204] Trial 1 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 211, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:34,281] Trial 2 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 64, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:34,439] Trial 3 finished with value: 0.656934306569343 and parameters: {'n_estimators': 206, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:34,648] Trial 4 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 65, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:35,523] Trial 5 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 275, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:35,768] Trial 6 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 75, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:35,977] Trial 7 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 74, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:36,096] Trial 8 finished with value: 0.6788321167883211 and parameters: {'n_estimators': 148, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:36,232] Trial 9 finished with value: 0.708029197080292 and parameters: {'n_estimators': 153, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:36,416] Trial 10 finished with value: 0.5620437956204379 and parameters: {'n_estimators': 248, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:36,964] Trial 11 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 199, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:37,064] Trial 12 finished with value: 0.6715328467153284 and parameters: {'n_estimators': 118, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:37,766] Trial 13 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 236, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:38,211] Trial 14 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 179, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 1 with value: 0.7518248175182481.
# [I 2025-06-02 20:09:38,702] Trial 15 finished with value: 0.7737226277372263 and parameters: {'n_estimators': 186, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:38,935] Trial 16 finished with value: 0.635036496350365 and parameters: {'n_estimators': 291, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:39,573] Trial 17 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 227, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:40,233] Trial 18 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 166, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:40,342] Trial 19 finished with value: 0.5985401459854015 and parameters: {'n_estimators': 122, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:40,831] Trial 20 finished with value: 0.7737226277372263 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:41,277] Trial 21 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 203, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:41,865] Trial 22 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 183, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:42,449] Trial 23 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 261, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:43,246] Trial 24 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 226, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:43,625] Trial 25 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 133, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:44,265] Trial 26 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 208, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:44,629] Trial 27 finished with value: 0.7226277372262774 and parameters: {'n_estimators': 188, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:44,795] Trial 28 finished with value: 0.7007299270072993 and parameters: {'n_estimators': 159, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:44,910] Trial 29 finished with value: 0.6934306569343066 and parameters: {'n_estimators': 106, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:45,647] Trial 30 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 217, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:46,118] Trial 31 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 181, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:46,567] Trial 32 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 170, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:46,949] Trial 33 finished with value: 0.7153284671532847 and parameters: {'n_estimators': 196, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:47,581] Trial 34 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 251, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:47,695] Trial 35 finished with value: 0.5912408759124088 and parameters: {'n_estimators': 140, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:47,708] Trial 36 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 175, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:48,502] Trial 37 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 215, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:48,926] Trial 38 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 192, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:48,988] Trial 39 finished with value: 0.6496350364963503 and parameters: {'n_estimators': 53, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:49,756] Trial 40 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 240, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:50,483] Trial 41 finished with value: 0.7299270072992701 and parameters: {'n_estimators': 224, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:51,123] Trial 42 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 214, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:51,948] Trial 43 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 214, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:52,465] Trial 44 finished with value: 0.7445255474452555 and parameters: {'n_estimators': 167, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:53,185] Trial 45 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 199, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:53,425] Trial 46 finished with value: 0.6861313868613139 and parameters: {'n_estimators': 267, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:53,551] Trial 47 finished with value: 0.6204379562043796 and parameters: {'n_estimators': 149, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:54,134] Trial 48 finished with value: 0.7518248175182481 and parameters: {'n_estimators': 236, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.
# [I 2025-06-02 20:09:54,726] Trial 49 finished with value: 0.7372262773722628 and parameters: {'n_estimators': 180, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 15 with value: 0.7737226277372263.

# %%
results_tuned
# Out:
#                   Model      F1  Accuracy  ROC_AUC  Tuned
# 0                   XGB  0.7826    0.7953   0.8656   True
# 1          RandomForest  0.7389    0.7602   0.8460   True
# 2      GradientBoosting  0.7636    0.7719   0.8546   True
# 3              CatBoost  0.7799    0.7953   0.8661   True
# 4  HistGradientBoosting  0.7702    0.7836   0.8550   True
# 5            ExtraTrees  0.7368    0.7661   0.8637   True

# %%
plot_metrics_comparison(results_tuned)

# %%
combined_results = pd.concat([results_untuned, results_tuned], ignore_index=True)
display(combined_results.sort_values(by=["Accuracy"], ascending=False))
# Out:
#                    Model  Accuracy  ROC_AUC      F1  Tuned
# 0                    XGB    0.8012   0.8671  0.7875  False
# 9               CatBoost    0.7953   0.8661  0.7799   True
# 6                    XGB    0.7953   0.8656  0.7826   True
# 4   HistGradientBoosting    0.7953   0.8663  0.7799  False
# 2       GradientBoosting    0.7895   0.8618  0.7778  False
# 3               CatBoost    0.7836   0.8654  0.7730  False
# 10  HistGradientBoosting    0.7836   0.8550  0.7702   True
# 8       GradientBoosting    0.7719   0.8546  0.7636   True
# 11            ExtraTrees    0.7661   0.8637  0.7368   True
# 7           RandomForest    0.7602   0.8460  0.7389   True
# 1           RandomForest    0.7485   0.8500  0.7226  False
# 5             ExtraTrees    0.7193   0.8229  0.6842  False

# %%
def plot_all_metrics(combined_results):
    melted = combined_results.melt(
        id_vars=["Model", "Tuned"],
        value_vars=['Accuracy', 'ROC_AUC', 'F1'],
        var_name="Metric",
        value_name="Score"
    )

    plt.figure(figsize=(15, 5))
    sns.set(style="whitegrid")

    g = sns.catplot(
        data=melted,
        x="Score",
        y="Model",
        hue="Tuned",
        col="Metric",
        kind="bar",
        palette="Set2",
        sharex=False,
        height=5,
        aspect=1.2
    )

    g.fig.subplots_adjust(top=0.85)
    g.fig.suptitle("Сравнение моделей по метрикам (до и после тюнинга)")
    plt.show()
plot_all_metrics(combined_results)

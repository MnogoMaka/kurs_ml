# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier, ExtraTreesClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import optuna

# %%
# Устанавливаем глобальное начальное состояние генератора случайных чисел
np.random.seed(42)

# %%
df = pd.read_csv('data/df_si_iqr.csv')

# %%
# Найдем медиану по столбцу и добавим бинарное значение в датафрейм
median_si = df['SI'].median()
df['SI_binary'] = (df['SI'] > median_si).astype(int)

# %%
# Проверим баланс классов
df['SI_binary'].value_counts()
# Out:
# SI_binary
# 1    438
# 0    438
# Name: count, dtype: int64

# %% [markdown]
# Анализ целевой переменной показал, что классы идеально сбалансированы. Применение методов коррекции не требуется.

# %%
# Разделяем данные
X = df.drop(columns=['SI', 'SI_binary'])
y = df['SI_binary']

# %%
# Делим исходные данные на тренировочную и тестовую выборки
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Теперь необходимо выбрать оптимальную модель.
#
# Для построения предсказательной модели были рассмотрены следующие алгоритмы:
#
# * XGBClassifier;
#
# * RandomForestClassifier;
#
# * GradientBoostingClassifier;
#
# * CatBoostClassifier;
#
# * HistGradientBoostingClassifier;
#
# * ExtraTreesClassifier.

# %%
models = {
    'XGB': XGBClassifier( eval_metric='logloss'),
    'RandomForest': RandomForestClassifier(),
    'GradientBoosting': GradientBoostingClassifier(),
    'CatBoost': CatBoostClassifier(verbose=0),
    'HistGradientBoosting': HistGradientBoostingClassifier(),
    'ExtraTrees': ExtraTreesClassifier()
}

# %%
def evaluate_models(models, X_train_full, y_train_full, X_test, y_test):
    results = []

    for name, model in models.items():
        pipeline = Pipeline([
            ('classifier', model)
        ])

        pipeline.fit(X_train_full, y_train_full)
        y_pred = pipeline.predict(X_test)

        y_pred_proba = pipeline.predict_proba(X_test)[:, 1]
        roc_auc = roc_auc_score(y_test, y_pred_proba)
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        results.append({
            'Model': name,
            'Accuracy': round(accuracy, 4),
            'ROC_AUC': round(roc_auc, 4) if roc_auc is not None else None,
            'F1': round(f1, 4),
            'Tuned': False
        })

    return pd.DataFrame(results)
results_untuned = evaluate_models(models, X_train_full, y_train_full, X_test, y_test)
display(results_untuned)
# Out:
#                   Model  Accuracy  ROC_AUC      F1  Tuned
# 0                   XGB    0.6420   0.7233  0.6595  False
# 1          RandomForest    0.6193   0.6791  0.6298  False
# 2      GradientBoosting    0.6364   0.7121  0.6667  False
# 3              CatBoost    0.6477   0.7030  0.6667  False
# 4  HistGradientBoosting    0.6591   0.7048  0.6667  False
# 5            ExtraTrees    0.6591   0.7008  0.6552  False

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_metrics_comparison(results_df):
    metrics = ['Accuracy', 'ROC_AUC', 'F1']
    fig, axs = plt.subplots(1, 3, figsize=(18, 5))

    for i, metric in enumerate(metrics):
        sns.barplot(data=results_df, x='Model', y=metric, ax=axs[i])
        axs[i].set_title(f'Сравнение моделей по {metric}')
        axs[i].set_xticks(range(len(results_df['Model'])))
        axs[i].set_xticklabels(results_df['Model'], rotation=45, ha='right')

    plt.tight_layout()
    plt.show()

plot_metrics_comparison(results_untuned)

# %%
def optuna_tuning(models, n_trials=50):
    results = []
    trained_models = {}

    # Проходим по всем моделям из переданного словаря
    for model_key, model in models.items():
        # Разбиваем данные на train/validation
        X_train, X_valid, y_train, y_valid = train_test_split(
            X_train_full, y_train_full, test_size=0.2, random_state=42
        )

        # Определяем функцию-цель для Optuna
        def objective(trial):
            # Для каждой модели формируем свой словарь параметров
            if model_key == 'XGB':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 500),
                    'max_depth': trial.suggest_int('max_depth', 3, 10),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'subsample': trial.suggest_float('subsample', 0.5, 1.0),
                    'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
                    'gamma': trial.suggest_float('gamma', 0, 5),
                    'min_child_weight': trial.suggest_int('min_child_weight', 1, 10)
                }
                reg = XGBClassifier(**params)

            elif model_key == 'RandomForest':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 300),
                    'max_depth': trial.suggest_int('max_depth', 3, 20),
                    'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
                    'max_features': trial.suggest_categorical('max_features', ['log2', 'sqrt', None])
                }
                reg = RandomForestClassifier(**params)

            elif model_key == 'GradientBoosting':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 300),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'max_depth': trial.suggest_int('max_depth', 3, 10),
                    'subsample': trial.suggest_float('subsample', 0.5, 1.0),
                    'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
                    'max_features': trial.suggest_categorical('max_features', [None, 'sqrt', 'log2'])
                }
                reg = GradientBoostingClassifier(**params, random_state=42)

            elif model_key == 'CatBoost':
                params = {
                    'iterations': trial.suggest_int('iterations', 100, 1000),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'depth': trial.suggest_int('depth', 4, 10),
                    'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 10),
                    'bagging_temperature': trial.suggest_float('bagging_temperature', 0, 1)
                }
                reg = CatBoostClassifier(**params, verbose=False)

            elif model_key == 'HistGradientBoosting':
                params = {
                    'max_iter': trial.suggest_int('max_iter', 50, 300),
                    'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
                    'max_depth': trial.suggest_int('max_depth', 3, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 20),
                    'l2_regularization': trial.suggest_float('l2_regularization', 0, 1)
                }
                reg = HistGradientBoostingClassifier(**params)

            elif model_key == 'ExtraTrees':
                params = {
                    'n_estimators': trial.suggest_int('n_estimators', 50, 300),
                    'max_depth': trial.suggest_int('max_depth', 3, 20),
                    'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
                    'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
                    'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
                }
                reg = ExtraTreesClassifier(**params)

            # Обучаем на train и проверяем accuracy_score на valid
            reg.fit(X_train, y_train)
            y_pred = reg.predict(X_valid)
            return accuracy_score(y_valid, y_pred)

        # Запускаем оптимизацию Optuna
        study = optuna.create_study(direction='maximize')
        study.optimize(objective, n_trials=n_trials)

        # Формируем финальную модель с лучшими гиперпараметрами
        best_params = study.best_params

        if model_key == 'XGB':
            final_model = XGBClassifier(**best_params)

        elif model_key == 'RandomForest':
            final_model = RandomForestClassifier(**best_params)

        elif model_key == 'GradientBoosting':
            final_model = GradientBoostingClassifier(**best_params)

        elif model_key == 'CatBoost':
            final_model = CatBoostClassifier(**best_params, verbose=False)

        elif model_key == 'HistGradientBoosting':
            final_model = HistGradientBoostingClassifier(**best_params)

        elif model_key == 'ExtraTrees':
            final_model = ExtraTreesClassifier(**best_params)

        # Обучаем финальную модель на полном тренировочном наборе
        final_model.fit(X_train_full, y_train_full)

        # Сохраняем обученную модель в словарь trained_models
        trained_models[model_key] = final_model

        # Оцениваем финальную модель на тестовом наборе
        y_test_pred = final_model.predict(X_test)
        y_test_proba = final_model.predict_proba(X_test)[:, 1]
        
        test_f1 = f1_score(y_test, y_test_pred)
        test_accuracy = accuracy_score(y_test, y_test_pred)
        test_roc_auc = roc_auc_score(y_test, y_test_proba)

        # Сохраняем метрики в список results
        results.append({
            'Model': model_key,
            'F1': round(test_f1, 4),
            'Accuracy': round(test_accuracy, 4),
            'ROC_AUC': round(test_roc_auc, 4),
            'Tuned': True
        })

    # Превращаем список результатов в DataFrame
    results_tuned = pd.DataFrame(results)

    # Возвращаем две структуры: DataFrame и словарь обученных моделей
    return results_tuned, trained_models

# %%
results_tuned, trained_models = optuna_tuning(models)
# Out:
# [I 2025-06-02 20:35:06,678] A new study created in memory with name: no-name-61af129a-529b-4966-9842-b175ec8f725a
# [I 2025-06-02 20:35:07,241] Trial 0 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 362, 'max_depth': 7, 'learning_rate': 0.04959847427908435, 'subsample': 0.933968461827561, 'colsample_bytree': 0.7657223398073156, 'gamma': 3.826404365059353, 'min_child_weight': 2}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:07,843] Trial 1 finished with value: 0.6 and parameters: {'n_estimators': 423, 'max_depth': 6, 'learning_rate': 0.09577105634986843, 'subsample': 0.7295217336024649, 'colsample_bytree': 0.7068590063261344, 'gamma': 0.433624899140832, 'min_child_weight': 7}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:07,917] Trial 2 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 63, 'max_depth': 5, 'learning_rate': 0.26754959961402763, 'subsample': 0.8496993283760437, 'colsample_bytree': 0.6898009865184801, 'gamma': 3.9990889515767454, 'min_child_weight': 6}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:08,081] Trial 3 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 121, 'max_depth': 6, 'learning_rate': 0.12500315069771425, 'subsample': 0.8176571737506986, 'colsample_bytree': 0.5635830817314984, 'gamma': 3.49683186916961, 'min_child_weight': 3}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:08,390] Trial 4 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 109, 'max_depth': 7, 'learning_rate': 0.024575385419954316, 'subsample': 0.7949469880732403, 'colsample_bytree': 0.8665780559674474, 'gamma': 2.292661854929408, 'min_child_weight': 3}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:08,803] Trial 5 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 462, 'max_depth': 9, 'learning_rate': 0.15148666620366785, 'subsample': 0.778100527701055, 'colsample_bytree': 0.8168402318088939, 'gamma': 4.969220789208796, 'min_child_weight': 2}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:08,943] Trial 6 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 65, 'max_depth': 8, 'learning_rate': 0.06865629872243606, 'subsample': 0.9610485395916563, 'colsample_bytree': 0.5418527882959392, 'gamma': 2.789855146531084, 'min_child_weight': 9}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:09,295] Trial 7 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 393, 'max_depth': 10, 'learning_rate': 0.06901678512095567, 'subsample': 0.5046587968090671, 'colsample_bytree': 0.8576487940356854, 'gamma': 3.633880348240388, 'min_child_weight': 5}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:09,537] Trial 8 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 182, 'max_depth': 5, 'learning_rate': 0.013661417528790328, 'subsample': 0.9485469828087715, 'colsample_bytree': 0.7944128315807898, 'gamma': 2.4496577085737536, 'min_child_weight': 7}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:09,608] Trial 9 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 69, 'max_depth': 4, 'learning_rate': 0.23887393312823585, 'subsample': 0.5321050494658741, 'colsample_bytree': 0.5498798997869909, 'gamma': 4.756640623810744, 'min_child_weight': 4}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:10,044] Trial 10 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 314, 'max_depth': 3, 'learning_rate': 0.19750123851189857, 'subsample': 0.6274118953092599, 'colsample_bytree': 0.9696274082994392, 'gamma': 0.780477532855079, 'min_child_weight': 10}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:10,244] Trial 11 finished with value: 0.6071428571428571 and parameters: {'n_estimators': 270, 'max_depth': 8, 'learning_rate': 0.07791642442356746, 'subsample': 0.9943832541662442, 'colsample_bytree': 0.634988410853622, 'gamma': 1.6096956708988472, 'min_child_weight': 10}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:10,773] Trial 12 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 305, 'max_depth': 8, 'learning_rate': 0.05333204924712104, 'subsample': 0.9157553984183919, 'colsample_bytree': 0.6346894041086686, 'gamma': 3.182989051602622, 'min_child_weight': 1}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:10,998] Trial 13 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 222, 'max_depth': 8, 'learning_rate': 0.11954244722635507, 'subsample': 0.8967107069481096, 'colsample_bytree': 0.5011318273021913, 'gamma': 1.6108216906298123, 'min_child_weight': 8}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:11,286] Trial 14 finished with value: 0.65 and parameters: {'n_estimators': 364, 'max_depth': 10, 'learning_rate': 0.04498493568715156, 'subsample': 0.9990525326286438, 'colsample_bytree': 0.9414424619919433, 'gamma': 2.9180372741058345, 'min_child_weight': 9}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:11,568] Trial 15 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 373, 'max_depth': 10, 'learning_rate': 0.1906527434369263, 'subsample': 0.8754165093764833, 'colsample_bytree': 0.9978041923849201, 'gamma': 4.194662426165886, 'min_child_weight': 1}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:12,366] Trial 16 finished with value: 0.6071428571428571 and parameters: {'n_estimators': 496, 'max_depth': 9, 'learning_rate': 0.03382853381557194, 'subsample': 0.6978043766451524, 'colsample_bytree': 0.9240434690818664, 'gamma': 1.9220974998723084, 'min_child_weight': 5}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:12,713] Trial 17 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 353, 'max_depth': 7, 'learning_rate': 0.10776787276449616, 'subsample': 0.9993420003426339, 'colsample_bytree': 0.7620790643995762, 'gamma': 2.9359857847146005, 'min_child_weight': 8}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:13,088] Trial 18 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 430, 'max_depth': 9, 'learning_rate': 0.1649169819670115, 'subsample': 0.9240734175194343, 'colsample_bytree': 0.9213103336688392, 'gamma': 4.324980132328703, 'min_child_weight': 4}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:13,348] Trial 19 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 249, 'max_depth': 10, 'learning_rate': 0.04220672955571026, 'subsample': 0.6734295488964626, 'colsample_bytree': 0.9162338109473787, 'gamma': 3.6137783563722374, 'min_child_weight': 6}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:13,745] Trial 20 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 334, 'max_depth': 3, 'learning_rate': 0.14667758351529167, 'subsample': 0.8492774801523416, 'colsample_bytree': 0.7426542286227705, 'gamma': 1.1731386578729464, 'min_child_weight': 9}. Best is trial 0 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:13,953] Trial 21 finished with value: 0.6785714285714286 and parameters: {'n_estimators': 189, 'max_depth': 7, 'learning_rate': 0.07627898847115228, 'subsample': 0.9582578907401387, 'colsample_bytree': 0.6433459351007228, 'gamma': 2.8366617200374633, 'min_child_weight': 9}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:14,144] Trial 22 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 189, 'max_depth': 7, 'learning_rate': 0.09091406589329763, 'subsample': 0.962319863683222, 'colsample_bytree': 0.6277249651729894, 'gamma': 3.10233182689808, 'min_child_weight': 9}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:14,338] Trial 23 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 188, 'max_depth': 7, 'learning_rate': 0.09211259816924239, 'subsample': 0.9477597461840759, 'colsample_bytree': 0.6251396014013232, 'gamma': 3.3244717653817824, 'min_child_weight': 8}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:14,529] Trial 24 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 164, 'max_depth': 6, 'learning_rate': 0.0796561245871985, 'subsample': 0.8776767556552235, 'colsample_bytree': 0.6928371129446478, 'gamma': 3.8846897702910077, 'min_child_weight': 7}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:14,736] Trial 25 finished with value: 0.6642857142857143 and parameters: {'n_estimators': 234, 'max_depth': 5, 'learning_rate': 0.1296964677110169, 'subsample': 0.9542008372758267, 'colsample_bytree': 0.5964397373268668, 'gamma': 4.467897869903805, 'min_child_weight': 10}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:14,950] Trial 26 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 251, 'max_depth': 5, 'learning_rate': 0.13637789478795068, 'subsample': 0.8357039764669105, 'colsample_bytree': 0.5892002178512011, 'gamma': 4.4498832585764765, 'min_child_weight': 10}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:15,270] Trial 27 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 224, 'max_depth': 4, 'learning_rate': 0.010095368288924295, 'subsample': 0.9144889615603858, 'colsample_bytree': 0.6697013460384194, 'gamma': 4.564877756884218, 'min_child_weight': 10}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:15,476] Trial 28 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 297, 'max_depth': 6, 'learning_rate': 0.1843538249576303, 'subsample': 0.7641722472396411, 'colsample_bytree': 0.7390037653423063, 'gamma': 3.872504521309207, 'min_child_weight': 8}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:15,605] Trial 29 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 147, 'max_depth': 4, 'learning_rate': 0.10615147812950304, 'subsample': 0.8838701063493589, 'colsample_bytree': 0.5860107783266322, 'gamma': 4.983424005626006, 'min_child_weight': 7}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:16,108] Trial 30 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 230, 'max_depth': 6, 'learning_rate': 0.05715459366194397, 'subsample': 0.7232389505687824, 'colsample_bytree': 0.7246263357771963, 'gamma': 0.4029477404278996, 'min_child_weight': 2}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:16,292] Trial 31 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 186, 'max_depth': 7, 'learning_rate': 0.07851873327829756, 'subsample': 0.9650461823844454, 'colsample_bytree': 0.6603277858232066, 'gamma': 2.6793530562464913, 'min_child_weight': 9}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:16,449] Trial 32 finished with value: 0.6642857142857143 and parameters: {'n_estimators': 203, 'max_depth': 5, 'learning_rate': 0.09553844211906418, 'subsample': 0.9662302423187341, 'colsample_bytree': 0.5972445166085707, 'gamma': 3.140288611205827, 'min_child_weight': 9}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:16,575] Trial 33 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 132, 'max_depth': 5, 'learning_rate': 0.2956463175267151, 'subsample': 0.9242535875712226, 'colsample_bytree': 0.6001312898756759, 'gamma': 2.1595460061999763, 'min_child_weight': 6}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:16,774] Trial 34 finished with value: 0.65 and parameters: {'n_estimators': 276, 'max_depth': 5, 'learning_rate': 0.11462561393645582, 'subsample': 0.8096352714220348, 'colsample_bytree': 0.5315377554909484, 'gamma': 4.0545010926364915, 'min_child_weight': 10}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:16,878] Trial 35 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 93, 'max_depth': 6, 'learning_rate': 0.13292826452855427, 'subsample': 0.9740065159655884, 'colsample_bytree': 0.7751505493758531, 'gamma': 3.383323155938156, 'min_child_weight': 3}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:17,041] Trial 36 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 206, 'max_depth': 4, 'learning_rate': 0.2282264689645457, 'subsample': 0.9419248135752257, 'colsample_bytree': 0.6686233477377855, 'gamma': 3.784966674962118, 'min_child_weight': 8}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:17,193] Trial 37 finished with value: 0.65 and parameters: {'n_estimators': 156, 'max_depth': 6, 'learning_rate': 0.09891548546786666, 'subsample': 0.8557171897909454, 'colsample_bytree': 0.709750754678362, 'gamma': 4.621051357777179, 'min_child_weight': 9}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:17,541] Trial 38 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 273, 'max_depth': 7, 'learning_rate': 0.1727621729518818, 'subsample': 0.9033897537743266, 'colsample_bytree': 0.5182430763820728, 'gamma': 2.6171276387154507, 'min_child_weight': 4}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:17,862] Trial 39 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 407, 'max_depth': 5, 'learning_rate': 0.06365740810961008, 'subsample': 0.9756303414587977, 'colsample_bytree': 0.8355635261467951, 'gamma': 3.545376676938983, 'min_child_weight': 5}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:18,127] Trial 40 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 116, 'max_depth': 8, 'learning_rate': 0.02685512401517659, 'subsample': 0.9295490091651826, 'colsample_bytree': 0.5823606391648842, 'gamma': 2.3471842741566604, 'min_child_weight': 2}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:18,351] Trial 41 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 206, 'max_depth': 7, 'learning_rate': 0.08926012806615063, 'subsample': 0.9559336508708502, 'colsample_bytree': 0.6181516022276732, 'gamma': 3.02901827435459, 'min_child_weight': 9}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:18,499] Trial 42 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 173, 'max_depth': 7, 'learning_rate': 0.12627573500301373, 'subsample': 0.972536031405182, 'colsample_bytree': 0.5613257742763793, 'gamma': 3.0823832263202235, 'min_child_weight': 10}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:18,724] Trial 43 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 248, 'max_depth': 8, 'learning_rate': 0.09033263044682921, 'subsample': 0.948528748134079, 'colsample_bytree': 0.6453673620791779, 'gamma': 3.2972246770088978, 'min_child_weight': 9}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:18,854] Trial 44 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 141, 'max_depth': 6, 'learning_rate': 0.14656793895524897, 'subsample': 0.5723997271324486, 'colsample_bytree': 0.609657766577841, 'gamma': 4.172668892421555, 'min_child_weight': 7}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:19,020] Trial 45 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 196, 'max_depth': 7, 'learning_rate': 0.06798477443359845, 'subsample': 0.9814551286503589, 'colsample_bytree': 0.6863663745249282, 'gamma': 2.744708649789024, 'min_child_weight': 8}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:19,267] Trial 46 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 102, 'max_depth': 5, 'learning_rate': 0.05155382038549173, 'subsample': 0.8952061520562764, 'colsample_bytree': 0.5648133555917453, 'gamma': 0.12596214935885452, 'min_child_weight': 9}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:19,768] Trial 47 finished with value: 0.6071428571428571 and parameters: {'n_estimators': 292, 'max_depth': 4, 'learning_rate': 0.07889516681364292, 'subsample': 0.8657411895085682, 'colsample_bytree': 0.8091776552236423, 'gamma': 2.0564346480238225, 'min_child_weight': 10}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:20,244] Trial 48 finished with value: 0.65 and parameters: {'n_estimators': 232, 'max_depth': 6, 'learning_rate': 0.10489505446769576, 'subsample': 0.8205529692957856, 'colsample_bytree': 0.6471282997005013, 'gamma': 3.697762245380042, 'min_child_weight': 8}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:20,573] Trial 49 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 434, 'max_depth': 8, 'learning_rate': 0.11807421106803041, 'subsample': 0.9301999354156393, 'colsample_bytree': 0.7742609517513708, 'gamma': 2.4744872960810054, 'min_child_weight': 9}. Best is trial 21 with value: 0.6785714285714286.
# [I 2025-06-02 20:35:20,769] A new study created in memory with name: no-name-f57d4b55-0bed-4a10-91b1-e632b592ff61
# [I 2025-06-02 20:35:23,707] Trial 0 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 282, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 0 with value: 0.6285714285714286.
# [I 2025-06-02 20:35:24,878] Trial 1 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 109, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 1 with value: 0.6357142857142857.
# [I 2025-06-02 20:35:25,130] Trial 2 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 126, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6357142857142857.
# [I 2025-06-02 20:35:25,425] Trial 3 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 206, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 3 with value: 0.6428571428571429.
# [I 2025-06-02 20:35:28,170] Trial 4 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 298, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:28,825] Trial 5 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 66, 'max_depth': 18, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:29,117] Trial 6 finished with value: 0.65 and parameters: {'n_estimators': 242, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:29,513] Trial 7 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 296, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:31,475] Trial 8 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 180, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:32,231] Trial 9 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 85, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:32,638] Trial 10 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 236, 'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:32,919] Trial 11 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 250, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:33,302] Trial 12 finished with value: 0.65 and parameters: {'n_estimators': 252, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:33,620] Trial 13 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 214, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:33,988] Trial 14 finished with value: 0.65 and parameters: {'n_estimators': 291, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:35,846] Trial 15 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 164, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:36,221] Trial 16 finished with value: 0.65 and parameters: {'n_estimators': 270, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:36,510] Trial 17 finished with value: 0.65 and parameters: {'n_estimators': 220, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:37,979] Trial 18 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 181, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:38,459] Trial 19 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 260, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:39,375] Trial 20 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 151, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:40,158] Trial 21 finished with value: 0.65 and parameters: {'n_estimators': 125, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:41,576] Trial 22 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 156, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 4 with value: 0.6571428571428571.
# [I 2025-06-02 20:35:43,099] Trial 23 finished with value: 0.6642857142857143 and parameters: {'n_estimators': 198, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 23 with value: 0.6642857142857143.
# [I 2025-06-02 20:35:44,628] Trial 24 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 147, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 23 with value: 0.6642857142857143.
# [I 2025-06-02 20:35:47,197] Trial 25 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 195, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 23 with value: 0.6642857142857143.
# [I 2025-06-02 20:35:48,024] Trial 26 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 138, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 23 with value: 0.6642857142857143.
# [I 2025-06-02 20:35:49,122] Trial 27 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 100, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 23 with value: 0.6642857142857143.
# [I 2025-06-02 20:35:50,824] Trial 28 finished with value: 0.6714285714285714 and parameters: {'n_estimators': 229, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:35:53,913] Trial 29 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 281, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:35:56,123] Trial 30 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 224, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:35:57,593] Trial 31 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 197, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:35:58,841] Trial 32 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 169, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:00,254] Trial 33 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 187, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:02,871] Trial 34 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 234, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:05,993] Trial 35 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 268, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:06,331] Trial 36 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 204, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:07,335] Trial 37 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 127, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:08,908] Trial 38 finished with value: 0.6642857142857143 and parameters: {'n_estimators': 151, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:09,579] Trial 39 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 282, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:10,478] Trial 40 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 60, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:11,159] Trial 41 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 110, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:12,539] Trial 42 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 150, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:14,858] Trial 43 finished with value: 0.65 and parameters: {'n_estimators': 170, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:16,400] Trial 44 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 134, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:17,610] Trial 45 finished with value: 0.65 and parameters: {'n_estimators': 159, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:18,594] Trial 46 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 81, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:19,072] Trial 47 finished with value: 0.65 and parameters: {'n_estimators': 210, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:21,431] Trial 48 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 188, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:24,115] Trial 49 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 227, 'max_depth': 18, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:36:26,187] A new study created in memory with name: no-name-c9524ea6-b2e6-4dff-a08d-0ef5ce31727f
# [I 2025-06-02 20:36:26,681] Trial 0 finished with value: 0.65 and parameters: {'n_estimators': 241, 'learning_rate': 0.024914928993639084, 'max_depth': 7, 'subsample': 0.6573540104522057, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.65.
# [I 2025-06-02 20:36:28,662] Trial 1 finished with value: 0.6642857142857143 and parameters: {'n_estimators': 188, 'learning_rate': 0.11531854254172791, 'max_depth': 9, 'subsample': 0.5806221014304169, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:28,837] Trial 2 finished with value: 0.6071428571428571 and parameters: {'n_estimators': 93, 'learning_rate': 0.19365106243346528, 'max_depth': 8, 'subsample': 0.5789763349864948, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:29,663] Trial 3 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 185, 'learning_rate': 0.27335606233686754, 'max_depth': 3, 'subsample': 0.5144886835985119, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:29,897] Trial 4 finished with value: 0.5928571428571429 and parameters: {'n_estimators': 133, 'learning_rate': 0.28472232855611596, 'max_depth': 5, 'subsample': 0.8444280861495228, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:32,548] Trial 5 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 281, 'learning_rate': 0.12758405275609583, 'max_depth': 6, 'subsample': 0.6595243925039482, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:34,199] Trial 6 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 251, 'learning_rate': 0.20638976341019175, 'max_depth': 3, 'subsample': 0.7858175406948, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:35,198] Trial 7 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 91, 'learning_rate': 0.023048912571955616, 'max_depth': 5, 'subsample': 0.8824191153927349, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:35,565] Trial 8 finished with value: 0.6071428571428571 and parameters: {'n_estimators': 54, 'learning_rate': 0.0411487027926463, 'max_depth': 4, 'subsample': 0.6268987137464945, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:37,431] Trial 9 finished with value: 0.6 and parameters: {'n_estimators': 129, 'learning_rate': 0.28240037812965657, 'max_depth': 6, 'subsample': 0.9535079504875373, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:38,052] Trial 10 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 217, 'learning_rate': 0.10732143927029167, 'max_depth': 10, 'subsample': 0.7246766151924515, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:38,571] Trial 11 finished with value: 0.6642857142857143 and parameters: {'n_estimators': 215, 'learning_rate': 0.07830756497884594, 'max_depth': 8, 'subsample': 0.6985443165241239, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:38,863] Trial 12 finished with value: 0.6 and parameters: {'n_estimators': 185, 'learning_rate': 0.08322117905014932, 'max_depth': 9, 'subsample': 0.5011616772689345, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:39,381] Trial 13 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 212, 'learning_rate': 0.0776814326672176, 'max_depth': 8, 'subsample': 0.7314251461930569, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:40,128] Trial 14 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 299, 'learning_rate': 0.159256811733608, 'max_depth': 10, 'subsample': 0.5765947866231106, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:40,441] Trial 15 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 152, 'learning_rate': 0.14955530277146872, 'max_depth': 8, 'subsample': 0.7038076148281714, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:40,407] Trial 16 finished with value: 0.65 and parameters: {'n_estimators': 214, 'learning_rate': 0.06641145232867204, 'max_depth': 9, 'subsample': 0.7952123758322448, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:42,094] Trial 17 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 159, 'learning_rate': 0.10425372245466397, 'max_depth': 7, 'subsample': 0.6134694936442251, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:42,784] Trial 18 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 252, 'learning_rate': 0.17862281347253267, 'max_depth': 9, 'subsample': 0.5563046197314556, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:43,219] Trial 19 finished with value: 0.6 and parameters: {'n_estimators': 197, 'learning_rate': 0.22973083248962983, 'max_depth': 10, 'subsample': 0.6818241829527609, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:43,820] Trial 20 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 233, 'learning_rate': 0.051444310721470654, 'max_depth': 8, 'subsample': 0.9899721239316923, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:44,328] Trial 21 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 250, 'learning_rate': 0.010476628733842194, 'max_depth': 7, 'subsample': 0.6433998721758392, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:44,696] Trial 22 finished with value: 0.65 and parameters: {'n_estimators': 167, 'learning_rate': 0.10303161295865049, 'max_depth': 7, 'subsample': 0.762351398150738, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:45,302] Trial 23 finished with value: 0.65 and parameters: {'n_estimators': 232, 'learning_rate': 0.039164750448010606, 'max_depth': 9, 'subsample': 0.6126779229525106, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:45,852] Trial 24 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 271, 'learning_rate': 0.13042697136495454, 'max_depth': 7, 'subsample': 0.6998754782391606, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:47,361] Trial 25 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 197, 'learning_rate': 0.059940325389533144, 'max_depth': 6, 'subsample': 0.5514126908134505, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:47,870] Trial 26 finished with value: 0.6071428571428571 and parameters: {'n_estimators': 229, 'learning_rate': 0.08714835968251154, 'max_depth': 8, 'subsample': 0.6673138722075556, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:48,432] Trial 27 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 269, 'learning_rate': 0.025671557803938982, 'max_depth': 9, 'subsample': 0.607075023951116, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:51,500] Trial 28 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 270, 'learning_rate': 0.12628092526181406, 'max_depth': 9, 'subsample': 0.5935617939025305, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:51,960] Trial 29 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 300, 'learning_rate': 0.029418381254622455, 'max_depth': 10, 'subsample': 0.5378340453628093, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:52,552] Trial 30 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 201, 'learning_rate': 0.013973134847971708, 'max_depth': 9, 'subsample': 0.6327289355821777, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:53,077] Trial 31 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 205, 'learning_rate': 0.025801466770567348, 'max_depth': 9, 'subsample': 0.6371915682689016, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:53,458] Trial 32 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 181, 'learning_rate': 0.056098992428776, 'max_depth': 8, 'subsample': 0.583471162729593, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:53,805] Trial 33 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 150, 'learning_rate': 0.015951006289048157, 'max_depth': 9, 'subsample': 0.6675639644359158, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:54,120] Trial 34 finished with value: 0.6 and parameters: {'n_estimators': 137, 'learning_rate': 0.07437972246545785, 'max_depth': 8, 'subsample': 0.5336206764279771, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:54,589] Trial 35 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 173, 'learning_rate': 0.04318862169512598, 'max_depth': 10, 'subsample': 0.6054242031774542, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:55,860] Trial 36 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 114, 'learning_rate': 0.09097080299168726, 'max_depth': 9, 'subsample': 0.5701708425892762, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:36:56,346] Trial 37 finished with value: 0.65 and parameters: {'n_estimators': 196, 'learning_rate': 0.11819280280967207, 'max_depth': 8, 'subsample': 0.6948114629998214, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:00,838] Trial 38 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 277, 'learning_rate': 0.1413693642981386, 'max_depth': 10, 'subsample': 0.6467801618329716, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:01,550] Trial 39 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 260, 'learning_rate': 0.02765058072621232, 'max_depth': 9, 'subsample': 0.8051841584553416, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:03,798] Trial 40 finished with value: 0.6071428571428571 and parameters: {'n_estimators': 221, 'learning_rate': 0.044739873267204244, 'max_depth': 5, 'subsample': 0.7590063113123884, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:04,444] Trial 41 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 239, 'learning_rate': 0.012959963067332, 'max_depth': 7, 'subsample': 0.629067316323722, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:05,204] Trial 42 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 244, 'learning_rate': 0.06461671045954336, 'max_depth': 7, 'subsample': 0.6579781432558252, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:05,771] Trial 43 finished with value: 0.6 and parameters: {'n_estimators': 283, 'learning_rate': 0.03343772514138599, 'max_depth': 6, 'subsample': 0.5266101041169199, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:06,447] Trial 44 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 224, 'learning_rate': 0.29878241689035145, 'max_depth': 8, 'subsample': 0.7337259526980601, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:09,801] Trial 45 finished with value: 0.5857142857142857 and parameters: {'n_estimators': 207, 'learning_rate': 0.07542326179558102, 'max_depth': 8, 'subsample': 0.8648718025478, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:10,130] Trial 46 finished with value: 0.6 and parameters: {'n_estimators': 261, 'learning_rate': 0.09630538557276674, 'max_depth': 4, 'subsample': 0.6811062818984501, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:10,305] Trial 47 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 61, 'learning_rate': 0.2602939985283747, 'max_depth': 9, 'subsample': 0.5960523237495042, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:12,277] Trial 48 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 189, 'learning_rate': 0.1152185018581542, 'max_depth': 8, 'subsample': 0.7158375372122652, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:13,114] Trial 49 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 286, 'learning_rate': 0.1695837110132227, 'max_depth': 10, 'subsample': 0.6235158595788932, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6642857142857143.
# [I 2025-06-02 20:37:15,641] A new study created in memory with name: no-name-30bf7ad8-48d4-452e-b9be-a2e589b4fdc9
# [I 2025-06-02 20:37:24,554] Trial 0 finished with value: 0.6214285714285714 and parameters: {'iterations': 573, 'learning_rate': 0.20293709710025434, 'depth': 8, 'l2_leaf_reg': 5.0312418024333, 'bagging_temperature': 0.3037820809046894}. Best is trial 0 with value: 0.6214285714285714.
# [I 2025-06-02 20:37:37,017] Trial 1 finished with value: 0.6357142857142857 and parameters: {'iterations': 434, 'learning_rate': 0.07749447189310324, 'depth': 9, 'l2_leaf_reg': 7.86514561883957, 'bagging_temperature': 0.5460843115343113}. Best is trial 1 with value: 0.6357142857142857.
# [I 2025-06-02 20:37:39,717] Trial 2 finished with value: 0.6071428571428571 and parameters: {'iterations': 194, 'learning_rate': 0.1449519065002027, 'depth': 8, 'l2_leaf_reg': 3.0530750274823344, 'bagging_temperature': 0.3240083802240771}. Best is trial 1 with value: 0.6357142857142857.
# [I 2025-06-02 20:37:46,961] Trial 3 finished with value: 0.6357142857142857 and parameters: {'iterations': 956, 'learning_rate': 0.1913483729038164, 'depth': 7, 'l2_leaf_reg': 9.534270928474502, 'bagging_temperature': 0.46055010662263984}. Best is trial 1 with value: 0.6357142857142857.
# [I 2025-06-02 20:37:47,829] Trial 4 finished with value: 0.6357142857142857 and parameters: {'iterations': 303, 'learning_rate': 0.10673082403667232, 'depth': 5, 'l2_leaf_reg': 7.7571606143841745, 'bagging_temperature': 0.09653004939156251}. Best is trial 1 with value: 0.6357142857142857.
# [I 2025-06-02 20:38:00,491] Trial 5 finished with value: 0.6285714285714286 and parameters: {'iterations': 927, 'learning_rate': 0.06503738919418597, 'depth': 8, 'l2_leaf_reg': 2.256246542543767, 'bagging_temperature': 0.5247706148634899}. Best is trial 1 with value: 0.6357142857142857.
# [I 2025-06-02 20:38:12,956] Trial 6 finished with value: 0.6142857142857143 and parameters: {'iterations': 494, 'learning_rate': 0.2688471688645011, 'depth': 9, 'l2_leaf_reg': 5.56945072271397, 'bagging_temperature': 0.10199639403742966}. Best is trial 1 with value: 0.6357142857142857.
# ...
# [I 2025-06-02 20:42:12,452] Trial 38 finished with value: 0.6428571428571429 and parameters: {'max_iter': 153, 'learning_rate': 0.2161793369051794, 'max_depth': 6, 'min_samples_leaf': 6, 'l2_regularization': 0.5265719326138316}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:13,006] Trial 39 finished with value: 0.6357142857142857 and parameters: {'max_iter': 127, 'learning_rate': 0.0702637765009783, 'max_depth': 8, 'min_samples_leaf': 4, 'l2_regularization': 0.43268828524923114}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:13,238] Trial 40 finished with value: 0.6357142857142857 and parameters: {'max_iter': 175, 'learning_rate': 0.265438396399202, 'max_depth': 3, 'min_samples_leaf': 15, 'l2_regularization': 0.6710365813409128}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:14,088] Trial 41 finished with value: 0.65 and parameters: {'max_iter': 220, 'learning_rate': 0.29185758709905113, 'max_depth': 8, 'min_samples_leaf': 5, 'l2_regularization': 0.5529988314806272}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:14,480] Trial 42 finished with value: 0.6285714285714286 and parameters: {'max_iter': 210, 'learning_rate': 0.2815568711945676, 'max_depth': 7, 'min_samples_leaf': 20, 'l2_regularization': 0.3372072693171616}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:15,390] Trial 43 finished with value: 0.6357142857142857 and parameters: {'max_iter': 257, 'learning_rate': 0.23778807832336374, 'max_depth': 9, 'min_samples_leaf': 7, 'l2_regularization': 0.4534063525555692}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:16,025] Trial 44 finished with value: 0.6357142857142857 and parameters: {'max_iter': 237, 'learning_rate': 0.22398334702616435, 'max_depth': 5, 'min_samples_leaf': 2, 'l2_regularization': 0.6414370232955117}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:17,113] Trial 45 finished with value: 0.6357142857142857 and parameters: {'max_iter': 283, 'learning_rate': 0.28046045272082476, 'max_depth': 8, 'min_samples_leaf': 5, 'l2_regularization': 0.5136901398056256}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:17,717] Trial 46 finished with value: 0.6214285714285714 and parameters: {'max_iter': 190, 'learning_rate': 0.20246622019066945, 'max_depth': 7, 'min_samples_leaf': 10, 'l2_regularization': 0.9517453274552731}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:18,770] Trial 47 finished with value: 0.6285714285714286 and parameters: {'max_iter': 206, 'learning_rate': 0.08941505957984225, 'max_depth': 10, 'min_samples_leaf': 1, 'l2_regularization': 0.4201709008931662}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:19,124] Trial 48 finished with value: 0.6428571428571429 and parameters: {'max_iter': 102, 'learning_rate': 0.04292060481880522, 'max_depth': 8, 'min_samples_leaf': 9, 'l2_regularization': 0.49366049900347697}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:19,336] Trial 49 finished with value: 0.6571428571428571 and parameters: {'max_iter': 169, 'learning_rate': 0.2591022852742455, 'max_depth': 3, 'min_samples_leaf': 11, 'l2_regularization': 0.7109907639653366}. Best is trial 28 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:19,719] A new study created in memory with name: no-name-de619db6-36f0-4d84-a7bb-b0c590150188
# [I 2025-06-02 20:42:19,772] Trial 0 finished with value: 0.6642857142857143 and parameters: {'n_estimators': 56, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 0 with value: 0.6642857142857143.
# [I 2025-06-02 20:42:19,961] Trial 1 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 222, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.6642857142857143.
# [I 2025-06-02 20:42:20,079] Trial 2 finished with value: 0.65 and parameters: {'n_estimators': 166, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 0 with value: 0.6642857142857143.
# [I 2025-06-02 20:42:20,261] Trial 3 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 258, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.6642857142857143.
# [I 2025-06-02 20:42:20,354] Trial 4 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 129, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 0 with value: 0.6642857142857143.
# [I 2025-06-02 20:42:20,451] Trial 5 finished with value: 0.6714285714285714 and parameters: {'n_estimators': 133, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:20,592] Trial 6 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 177, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:20,758] Trial 7 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 213, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:20,850] Trial 8 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 107, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:20,980] Trial 9 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 171, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:21,207] Trial 10 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 60, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:21,409] Trial 11 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 50, 'max_depth': 19, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:21,507] Trial 12 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 100, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:21,583] Trial 13 finished with value: 0.6642857142857143 and parameters: {'n_estimators': 81, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:22,084] Trial 14 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 138, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:22,165] Trial 15 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 85, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:22,432] Trial 16 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 297, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:22,544] Trial 17 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 128, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:22,739] Trial 18 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 210, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:23,251] Trial 19 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 145, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:23,320] Trial 20 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 72, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:23,409] Trial 21 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 92, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:23,499] Trial 22 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 76, 'max_depth': 17, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:23,601] Trial 23 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 112, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:23,661] Trial 24 finished with value: 0.65 and parameters: {'n_estimators': 51, 'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:23,738] Trial 25 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 76, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:23,830] Trial 26 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 114, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:23,975] Trial 27 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 158, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:24,057] Trial 28 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 67, 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:24,802] Trial 29 finished with value: 0.6142857142857143 and parameters: {'n_estimators': 187, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:24,918] Trial 30 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 99, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:25,026] Trial 31 finished with value: 0.6714285714285714 and parameters: {'n_estimators': 128, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:25,151] Trial 32 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 151, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:25,254] Trial 33 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 124, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:25,336] Trial 34 finished with value: 0.65 and parameters: {'n_estimators': 87, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:25,480] Trial 35 finished with value: 0.65 and parameters: {'n_estimators': 194, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:25,669] Trial 36 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 255, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:25,784] Trial 37 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 117, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:25,899] Trial 38 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 139, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:26,037] Trial 39 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 165, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:26,107] Trial 40 finished with value: 0.6285714285714286 and parameters: {'n_estimators': 65, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:26,224] Trial 41 finished with value: 0.6642857142857143 and parameters: {'n_estimators': 132, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:26,338] Trial 42 finished with value: 0.65 and parameters: {'n_estimators': 130, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:26,430] Trial 43 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 101, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:26,568] Trial 44 finished with value: 0.6571428571428571 and parameters: {'n_estimators': 182, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:26,818] Trial 45 finished with value: 0.6214285714285714 and parameters: {'n_estimators': 84, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:26,957] Trial 46 finished with value: 0.6357142857142857 and parameters: {'n_estimators': 156, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:27,026] Trial 47 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 60, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:27,141] Trial 48 finished with value: 0.6428571428571429 and parameters: {'n_estimators': 136, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 5 with value: 0.6714285714285714.
# [I 2025-06-02 20:42:27,255] Trial 49 finished with value: 0.65 and parameters: {'n_estimators': 106, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 5 with value: 0.6714285714285714.

# %%
results_tuned
# Out:
#                   Model      F1  Accuracy  ROC_AUC  Tuned
# 0                   XGB  0.6067    0.6023   0.6731   True
# 1          RandomForest  0.6404    0.6364   0.6902   True
# 2      GradientBoosting  0.6484    0.6364   0.6972   True
# 3              CatBoost  0.6629    0.6591   0.6951   True
# 4  HistGradientBoosting  0.6292    0.6250   0.7051   True
# 5            ExtraTrees  0.6136    0.6136   0.6638   True

# %%
plot_metrics_comparison(results_tuned)

# %%
combined_results = pd.concat([results_untuned, results_tuned], ignore_index=True)
display(combined_results.sort_values(by=["Accuracy"], ascending=False))
# Out:
#                    Model  Accuracy  ROC_AUC      F1  Tuned
# 5             ExtraTrees    0.6591   0.7008  0.6552  False
# 9               CatBoost    0.6591   0.6951  0.6629   True
# 4   HistGradientBoosting    0.6591   0.7048  0.6667  False
# 3               CatBoost    0.6477   0.7030  0.6667  False
# 0                    XGB    0.6420   0.7233  0.6595  False
# 2       GradientBoosting    0.6364   0.7121  0.6667  False
# 8       GradientBoosting    0.6364   0.6972  0.6484   True
# 7           RandomForest    0.6364   0.6902  0.6404   True
# 10  HistGradientBoosting    0.6250   0.7051  0.6292   True
# 1           RandomForest    0.6193   0.6791  0.6298  False
# 11            ExtraTrees    0.6136   0.6638  0.6136   True
# 6                    XGB    0.6023   0.6731  0.6067   True

# %%
def plot_all_metrics(combined_results):
    melted = combined_results.melt(
        id_vars=["Model", "Tuned"],
        value_vars=['Accuracy', 'ROC_AUC', 'F1'],
        var_name="Metric",
        value_name="Score"
    )

    plt.figure(figsize=(15, 5))
    sns.set(style="whitegrid")

    g = sns.catplot(
        data=melted,
        x="Score",
        y="Model",
        hue="Tuned",
        col="Metric",
        kind="bar",
        palette="Set2",
        sharex=False,
        height=5,
        aspect=1.2
    )

    g.fig.subplots_adjust(top=0.85)
    g.fig.suptitle("Сравнение моделей по метрикам (до и после тюнинга)")
    plt.show()
plot_all_metrics(combined_results)
